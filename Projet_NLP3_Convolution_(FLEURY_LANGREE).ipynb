# %% [markdown]
# M2 project : Convolutions and character embeddings
# ======================

# %% [markdown]
# **FLEURY MANON 22410952/ LANGREE TOMMI 22312312**

# %% [markdown]
# The project aims to predict the language from which a character sequence comes from. This is done with surnames and it involves a dozen of languages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset
import warnings
from random import shuffle

# %% [markdown]
# Data download & description
# ---------------------

# %%
from urllib.request import urlretrieve

urlretrieve('http://www.linguist.univ-paris-diderot.fr/~bcrabbe/datasets/name2lang.train','name2lang.train')
urlretrieve('http://www.linguist.univ-paris-diderot.fr/~bcrabbe/datasets/name2lang.valid','name2lang.valid')

#Prints the beginning of the valid set
istream = open('name2lang.valid')
for idx, line in enumerate(istream):
  print(line.strip())
  if idx >=300:
    break
istream.close()
# Out:
# Barros, Portuguese
# Campos, Portuguese
# D'cruz, Portuguese
# Henriques, Portuguese
# Machado, Portuguese
# Silva, Portuguese
# Torres, Portuguese
# Ahearn, Irish
# Aonghus, Irish
# Brady, Irish
# Cearbhall, Irish
# Flann, Irish
# Kavanagh, Irish
# Maguire, Irish
# Mcmahon, Irish
# Mcneil, Irish
# Monahan, Irish
# Muirchertach, Irish
# Mullen, Irish
# O'Connell, Irish
# O'Grady, Irish
# O'Hara, Irish
# O'Mahony, Irish
# Rory, Irish
# Shannon, Irish
# Sioda, Irish
# Tadhgan, Irish
# Abel, Spanish
# Agramunt, Spanish
# Aldana, Spanish
# Alfaro, Spanish
# Aquino, Spanish
# Arena, Spanish
# Blanco, Spanish
# Bustos, Spanish
# Cardona, Spanish
# Castellano, Spanish
# Del olmo, Spanish
# Etxeberria, Spanish
# Garrastazu, Spanish
# Hierro, Spanish
# Loyola, Spanish
# Maradona, Spanish
# Mas, Spanish
# Nieves, Spanish
# Ortega, Spanish
# Pelaez, Spanish
# Robles, Spanish
# Roldan, Spanish
# Suero, Spanish
# Tomas, Spanish
# Torres, Spanish
# Tos, Spanish
# Ubina, Spanish
# Urena, Spanish
# Valdez, Spanish
# Varela, Spanish
# Vasquez, Spanish
# Villa, Spanish
# Villaverde, Spanish
# Zavala, Spanish
# Pham, Vietnamese
# Vu, Vietnamese
# Ho, Vietnamese
# Banh, Vietnamese
# Dinh, Vietnamese
# Kieu, Vietnamese
# La, Vietnamese
# Pho, Vietnamese
# Sai, Vietnamese
# Duan, Chinese
# Feng, Chinese
# Gong, Chinese
# Guo, Chinese
# Hew, Chinese
# Hong, Chinese
# Kau, Chinese
# Khu, Chinese
# Kwong, Chinese
# Loh, Chinese
# Que, Chinese
# See , Chinese
# Shen, Chinese
# Shuai, Chinese
# Tow, Chinese
# Zhang, Chinese
# Juan, Chinese
# Liang, Chinese
# Alexandropoulos, Greek
# Angelopoulos, Greek
# Antoniadis, Greek
# Comino, Greek
# Close, Greek
# Close, Greek
# Egonidis, Greek
# Giannakopoulos, Greek
# Hagias, Greek
# Karahalios, Greek
# Konstantatos, Greek
# Kotsiopoulos, Greek
# Matsoukis, Greek
# Paraskos, Greek
# Patrianakos, Greek
# Patselas, Greek
# Phocas, Greek
# Poniros, Greek
# Stamatelos, Greek
# Tselios, Greek
# Antonowitz, Czech
# Bartonova, Czech
# Blahut, Czech
# Blazek, Czech
# Brousil, Czech
# Bruckner, Czech
# Buchta, Czech
# Cermak, Czech
# Cerny, Czech
# Chemlik, Czech
# Chromy, Czech
# Cihak, Czech
# Cober, Czech
# Czabal, Czech
# Demko, Czech
# Fremut, Czech
# Gabrisova, Czech
# Gavalok, Czech
# Hanzlik, Czech
# Hartl, Czech
# Heidl, Czech
# Hiorvst, Czech
# Jaluvka, Czech
# Jirovy, Czech
# Kocian, Czech
# Kremlicka, Czech
# Kriz, Czech
# Kucharova, Czech
# Kofel, Czech
# Loskot, Czech
# Malecha, Czech
# Matocha, Czech
# MaxaB, Czech
# Navara, Czech
# Nemecek, Czech
# Nowak, Czech
# Opp, Czech
# Pfeifer, Czech
# Pokorny, Czech
# Pretsch, Czech
# Psik, Czech
# Rafaj, Czech
# Ruzicka, Czech
# Rypka, Czech
# Satorie, Czech
# Savchak, Czech
# Serak, Czech
# Slepicka, Czech
# Slivka, Czech
# Soucek, Czech
# Srda, Czech
# Steinborn, Czech
# Stramba, Czech
# Suchanka, Czech
# Svoboda, Czech
# Till, Czech
# Timpe, Czech
# Vrazel, Czech
# Weineltk, Czech
# Wondracek, Czech
# Zaruba, Czech
# Zwolenksy, Czech
# Agthoven, Dutch
# Alst, Dutch
# Assen, Dutch
# Ven, Dutch
# Venn, Dutch
# Haenraets, Dutch
# Hautum, Dutch
# Houtum, Dutch
# Karl, Dutch
# Klein, Dutch
# Klerk, Dutch
# Klerken, Dutch
# Kloeter, Dutch
# Kuijpers, Dutch
# Kuiper, Dutch
# Marquerink, Dutch
# Meeuweszen, Dutch
# Mohren, Dutch
# Rietveld, Dutch
# Rompaey, Dutch
# Samson, Dutch
# Schneiders, Dutch
# Schoorel, Dutch
# Snell, Dutch
# Snyder, Dutch
# Spijker, Dutch
# Aoki, Japanese
# Asano, Japanese
# Asanuma, Japanese
# Ayabito, Japanese
# Daishi, Japanese
# Eguchi, Japanese
# Fujioka, Japanese
# Fujishima, Japanese
# Fukayama, Japanese
# Fukushima, Japanese
# Fumihiko, Japanese
# Fuschida, Japanese
# Fuwa, Japanese
# Handa, Japanese
# Hasimoto, Japanese
# Hayakawa, Japanese
# Hida, Japanese
# Hirata, Japanese
# Hiroyuki, Japanese
# Ichisada, Japanese
# Ienari, Japanese
# Imai, Japanese
# Irie, Japanese
# Itagaki, Japanese
# Ito, Japanese
# Iwasa, Japanese
# Kahae, Japanese
# Kahaya, Japanese
# Kanegawa, Japanese
# Kasai, Japanese
# Katsukawa, Japanese
# Kihara, Japanese
# Kikkawa, Japanese
# Kikutake, Japanese
# Kimura, Japanese
# Ko, Japanese
# Konda, Japanese
# Kurata, Japanese
# Maeda, Japanese
# Marubeni, Japanese
# Maruya, Japanese
# Mashita, Japanese
# Matsura, Japanese
# Matsuzawa, Japanese
# Miyamoto, Japanese
# Mizutani, Japanese
# Monomonoi, Japanese
# Morimoto, Japanese
# Munakata, Japanese
# Muraguchi, Japanese
# Mutsu, Japanese
# Nagahama, Japanese
# Nagano, Japanese
# Nakamura, Japanese
# Nakanoi, Japanese
# Nemoto, Japanese
# Nijo, Japanese
# Nogushi, Japanese
# Okabe, Japanese
# Okamoto, Japanese
# Okasawa, Japanese
# Okuda, Japanese
# Otsuka, Japanese
# Sada, Japanese
# Satoh, Japanese
# Shibasawa, Japanese
# Shigi, Japanese
# Shimanouchi, Japanese
# Shimon, Japanese
# Shionoya, Japanese
# Shiraishi, Japanese
# Shunsen, Japanese
# Soseki, Japanese
# Suenami, Japanese
# Sugitani, Japanese
# Sugiyama, Japanese
# Sumitimo, Japanese
# Taguchi, Japanese
# Taira, Japanese
# Takahama, Japanese
# Takamura, Japanese
# Takara, Japanese
# Takemitsu, Japanese
# Taku, Japanese
# Tarumi, Japanese
# Tomika, Japanese
# Tomonaga, Japanese
# Toshishai, Japanese
# Uchiyama, Japanese
# Umari, Japanese
# Wakatsuki, Japanese
# Yamakawa, Japanese
# Yamura, Japanese
# Yasuhiro, Japanese
# Yasui, Japanese
# Yoshifumi, Japanese
# Armistead, French
# Baudin, French
# Beaulieu, French
# Bertrand, French
# Bissette, French
# Blanc, French
# Bonfils, French
# Charbonneau, French
# Charpentier, French

# %%
istream = open('name2lang.train')
for idx, line in enumerate(istream):
  print(line.strip())
  if idx >=6:
    break
istream.close()
# Out:
# Abreu, Portuguese
# Albuquerque, Portuguese
# Almeida, Portuguese
# Alves, Portuguese
# Araujo, Portuguese
# Araullo, Portuguese
# Basurto, Portuguese

# %% [markdown]
# First exercise : data preprocessing (3pts)
# ---
# The first exercise amounts to create encodings from integers to strings and from strings to integers.

# %%
def vocabulary(filename,char_vocab,pad_token='<pad>'):
    """
    Args:
      filename (str)    : the name of the file
      char_vocab (bool) : selects if we extract char symbols or language codes
      pad_token(str)    : the value of the pad symbol
    """
    #char_vocab is a boolean flag that tells if we extract char symbols or language codes
    # idx2sym : map index to symbol -> caracters
    # sym2idx : map symbol to index -> integers

    idx2sym = []
    sym2idx = {}
    idx2sym.append(pad_token)
    sym2idx[pad_token] = 0

    istream = open(filename)
    for line in istream:
      line = line.strip()

      if char_vocab: # we extract char symbols
        for i,char in enumerate(line):
          if char not in sym2idx: # or idx2sym
            idx2sym.append(char)
            sym2idx[char] = len(idx2sym) - 1
      else: # we want to extract language codes
        line = line.split(', ')
        if len(line) > 1:
          code = line[1]
          if code not in sym2idx:
            idx2sym.append(code)
            sym2idx[code] = len(idx2sym) - 1

    #return the two encoding maps idx2sym and sym2idx as a couple
    return idx2sym, sym2idx

# %%
# test with TRUE
filename = 'name2lang.train'
idx2sym, sym2idx = vocabulary(filename, True)
print(idx2sym)
print(sym2idx)
#print(idx2sym[24])
#print(sym2idx['h']) # 24
# Out:
# ['<pad>', 'A', 'b', 'r', 'e', 'u', ',', ' ', 'P', 'o', 't', 'g', 's', 'l', 'q', 'm', 'i', 'd', 'a', 'v', 'j', 'B', 'C', 'z', 'h', 'p', 'D', "'", 'c', 'n', 'E', 'F', 'G', 'L', 'M', 'N', 'R', 'S', 'f', 'V', 'I', 'y', 'k', 'H', 'J', 'K', 'O', 'w', 'T', 'Q', 'W', 'x', 'U', 'Y', 'Z', 'X']
# {'<pad>': 0, 'A': 1, 'b': 2, 'r': 3, 'e': 4, 'u': 5, ',': 6, ' ': 7, 'P': 8, 'o': 9, 't': 10, 'g': 11, 's': 12, 'l': 13, 'q': 14, 'm': 15, 'i': 16, 'd': 17, 'a': 18, 'v': 19, 'j': 20, 'B': 21, 'C': 22, 'z': 23, 'h': 24, 'p': 25, 'D': 26, "'": 27, 'c': 28, 'n': 29, 'E': 30, 'F': 31, 'G': 32, 'L': 33, 'M': 34, 'N': 35, 'R': 36, 'S': 37, 'f': 38, 'V': 39, 'I': 40, 'y': 41, 'k': 42, 'H': 43, 'J': 44, 'K': 45, 'O': 46, 'w': 47, 'T': 48, 'Q': 49, 'W': 50, 'x': 51, 'U': 52, 'Y': 53, 'Z': 54, 'X': 55}

# %%
# test with FALSE
filename = 'name2lang.train'
idx2sym, sym2idx = vocabulary(filename, False)
print(idx2sym)
print(sym2idx)
# Out:
# ['<pad>', 'Portuguese', 'Irish', 'Spanish', 'Vietnamese', 'Chinese', 'Greek', 'Czech', 'Dutch', 'Japanese', 'French', 'German', 'Scottish', 'English', 'Russian', 'Polish', 'Arabic', 'Korean', 'Italian']
# {'<pad>': 0, 'Portuguese': 1, 'Irish': 2, 'Spanish': 3, 'Vietnamese': 4, 'Chinese': 5, 'Greek': 6, 'Czech': 7, 'Dutch': 8, 'Japanese': 9, 'French': 10, 'German': 11, 'Scottish': 12, 'English': 13, 'Russian': 14, 'Polish': 15, 'Arabic': 16, 'Korean': 17, 'Italian': 18}

# %%
def pad_sequence(sequence,pad_size,pad_token):
    '''pad_size : The final length that the sequence should have after adding padding characters.'''
    L_seq_pad = list(sequence)

    if len(sequence) < pad_size:
      for i in range(pad_size-len(sequence)):
        L_seq_pad.append(pad_token)

    if len(sequence) > pad_size:
      L_seq_pad = L_seq_pad[:pad_size]

    return L_seq_pad #returns a list with additional pad tokens to match pad_size if needed


def code_sequence(charseq,encodingmap): # encodingmap = dico sym2idx
  #we ignore chars not seen in train set
  #charseq is a sequence of chars
  return [encodingmap[c] for c in charseq if c in encodingmap]

def decode_sequence(idxseq,decodingmap): #decodingmap = idx2sym
  #idxseq is a list of integers
  return [decodingmap[idx] for idx in idxseq]

# %% [markdown]
# Second exercise : data generator (2pt)
# ------------

# %% [markdown]
# The data generator aims to deliver efficiently well formed batches of data to the model.

# %%
def read_dataset(filename,input_symbols):
    '''reads from a raw datafile, either the surnames if input_symbols is True otherwise it reads the language
    <=> if input_symbol=True => surnames
        if input_symbol=False => nationality'''
    symbols = []
    istream = open(filename)
    for line in istream:
      if line and not line.isspace():
        word,lang = line.split(',')
        symbol = list(word.strip()) if input_symbols else lang.strip()
        symbols.append(symbol)
    istream.close()
    return symbols

# %%
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence
import torch

# DataGenerator class for loading and preparing data
class DataGenerator(Dataset):
    def __init__(self, data_path, parentgenerator=None):
        self.data = self.load_data(data_path)
        self.pad_token = '<PAD>'
        if parentgenerator:
            # Reuse mappings from parent generator
            self.input_sym2idx = parentgenerator.input_sym2idx
            self.input_idx2sym = parentgenerator.input_idx2sym
            self.output_sym2idx = parentgenerator.output_sym2idx
            self.output_idx2sym = parentgenerator.output_idx2sym
        else:
            self.create_mappings()

    def load_data(self, data_path):
        # Load data from file (name,label)
        data = []
        with open(data_path, 'r', encoding='utf-8') as f:
            for line in f:
                parts = line.strip().split(',')
                if len(parts) >= 2:
                    name = parts[0]
                    label = ','.join(parts[1:]).strip()  # Handle labels with commas
                    data.append((name, label))
        return data

    def create_mappings(self):
        # Create character and label mappings
        chars = set()
        labels = set()
        for name, label in self.data:
            chars.update(name)
            labels.add(label)
        # Map characters to indices (start from 1)
        self.input_sym2idx = {char: idx + 1 for idx, char in enumerate(sorted(chars))}
        self.input_sym2idx[self.pad_token] = 0  # Padding token at index 0
        self.input_idx2sym = {idx: char for char, idx in self.input_sym2idx.items()}
        # Map labels to indices
        self.output_sym2idx = {label: idx for idx, label in enumerate(sorted(labels))}
        self.output_idx2sym = {idx: label for label, idx in self.output_sym2idx.items()}

    def generate_batches(self, batch_size):
        # Generate batches of data
        data = self.data.copy()
        for i in range(0, len(data), batch_size):
            batch_data = data[i:i + batch_size]
            seqX = []
            seqY = []
            for word, lang in batch_data:
                # Convert characters to indices
                x = [self.input_sym2idx.get(char, self.input_sym2idx[self.pad_token]) for char in word]
                seqX.append(torch.tensor(x, dtype=torch.long))
                # Get label index
                y = self.output_sym2idx[lang]
                seqY.append(y)
            # Pad sequences to the same length
            seqX = pad_sequence(seqX, batch_first=True, padding_value=self.input_sym2idx[self.pad_token])
            yield seqX, seqY

# %% [markdown]
# Third exercise : Implement the word embedding submodule (5pts)
# -----
# This exercise amounts to implement a pytorch submodule that takes as input a sequence of char indexes and outputs the word embedding corresponding for the sequence.
#
# The module contains no training method and is meant to be used in a larger network. Its use is quite similar to `nn.Embedding`

# %%
import torch
import torch.nn as nn

class CharConvolution(nn.Module):

      def __init__(self,windowK,chars_vocab_size,input_embedding_size,output_embedding_size,padding_idx = None):
          """A minimalist convnet with max pooling
          Args:
          windowK (int): size of the window, positive integer
          chars_vocab_size(int): size of the character vocabulary
          input_embedding_size (int): size of each embedding vector
          output_embedding_size (int): number of output channels (number of kernels), >=1
          padding_idx (int, optional): the index for padding token (0 in our case)"""
          super(CharConvolution, self).__init__()
          self.embedding = nn.Embedding(chars_vocab_size, input_embedding_size, padding_idx=padding_idx)
          M = (2*windowK)+1
          self.convlayer = nn.Conv1d(input_embedding_size, output_embedding_size, M, padding=windowK)

      def forward(self,xinput):
          """Args:
          xinput: a tensor [batch,seq] where seq the sequence length
          Returns:
          A tensor with the max_pooled result along the sequence dimension"""
          #Implement the forward method, taking an input of the form [batch,seq] and return the max pooled result
          x_embed = self.embedding(xinput) # # output shape: [batch, seq, embedding_size]
          #Rearrange dimensions for Conv1d which expects [batch, embedding_size, seq]
          x_embed = x_embed.permute(0, 2, 1)  # output shape: [batch, embedding_size, seq]
          # Apply convolution layer and max-pooling
          x_conv = self.convlayer(x_embed)  # output shape: [batch, output_embedding_size, new_seq]
          x_pooled = nn.MaxPool1d(x_conv.size(2))(x_conv)  # apply max pooling along the sequence dimension
          # Remove the extra dimension added by pooling, resulting in [batch, output_embedding_size]
          return x_pooled.squeeze(-1)

# %%
# Example parameters
windowK = 3  # Size of the convolutional window
chars_vocab_size = 100  # Number of unique characters
input_embedding_size = 64  # Size of each embedding
output_embedding_size = 32  # Number of output features
padding_idx = 0  # Index for the padding token

# instance of CharConvolution
char_conv = CharConvolution(windowK, chars_vocab_size, input_embedding_size, output_embedding_size, padding_idx)

# Example input (e.g., [batch_size, seq_length])
example_input = torch.LongTensor([[1, 2, 3, 0, 4], [1, 0, 2, 3, 4]])  # Batch of 2 sequences

# Forward pass through the CharConvolution
output = char_conv(example_input)
print(output.shape)  # Should be [batch_size, output_embedding_size]
# Out:
# torch.Size([2, 32])

# %% [markdown]
# Fourth Exercise : predict the target language (10pts)
# -------
# In this exercise, we aim to predict the target language from a word char embedding. You will implement for the `LanguageIdentifier` class:
# * A forward function: the function takes as input a char index tensor and returns a vector of prediction for each word
# * A train function: the function trains the model on the full dataset (with early stopping)
# * A predict function: the function takes a test corpus (a list of words)
# and predicts the language. The function outputs its results in textual form. Each word is printed on the same line as its predicted class.
#
# Once implemented you are expected to search for hyperparameters in the main program.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset
import warnings

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')



# LanguageIdentifier model
class LanguageIdentifier(nn.Module):
    def __init__(self, datagenerator, window_size, char_embedding_size, word_embedding_size):
        super(LanguageIdentifier, self).__init__()
        invocab_size = len(datagenerator.input_idx2sym)
        outvocab_size = len(datagenerator.output_idx2sym)
        pad_idx = datagenerator.input_sym2idx[datagenerator.pad_token]
        self.charE = CharConvolution(window_size, invocab_size, char_embedding_size, word_embedding_size, padding_idx=pad_idx)
        self.output = nn.Linear(word_embedding_size, outvocab_size)

    def load(self, filename):
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=FutureWarning)
            self.load_state_dict(torch.load(filename))

    def forward(self, xinput):
        word_embeddings = self.charE(xinput)  # [batch_size, word_embedding_size]
        return self.output(word_embeddings)  # [batch_size, outvocab_size]

    def train_model(self, traingenerator, validgenerator, epochs, batch_size, device='cpu', learning_rate=0.001):
        self.to(device)
        optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2)
        loss_fn = nn.CrossEntropyLoss()
        self.minloss = float('inf')
        patience = 5
        patience_counter = 0

        for epoch in range(1, epochs + 1):
            self.train()
            total_loss = 0
            for seqX, seqY in traingenerator.generate_batches(batch_size):
                X = seqX.to(device)
                Y = torch.tensor(seqY, dtype=torch.long).to(device)

                optimizer.zero_grad()
                Yhat = self.forward(X)
                loss = loss_fn(Yhat, Y)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            avg_loss = total_loss / len(traingenerator.data) * batch_size
            valid_loss, valid_acc = self.validate(validgenerator, batch_size, device)
            scheduler.step(valid_loss)
            print(f'Epoch [{epoch}/{epochs}], Loss: {avg_loss:.4f}, Validation Loss: {valid_loss:.4f}, Validation Acc: {valid_acc:.2f}%')

            if valid_loss < self.minloss:
                self.minloss = valid_loss
                patience_counter = 0
                torch.save(self.state_dict(), 'best_model.pth')
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print("Early stopping triggered.")
                    break

    def predict(self, datagenerator, batch_size, device):
          self.eval()
          predictions = []
          actual_labels = []
          device = torch.device(device)

          for seqX, seqY in datagenerator.generate_batches(batch_size):
              X = seqX.to(device)
              Y = torch.tensor(seqY, dtype=torch.long).to(device)
              with torch.no_grad():
                  logits = self.forward(X)
                  Yhat = torch.argmax(logits, dim=1)
                  predictions.extend(Yhat.cpu().numpy())
                  actual_labels.extend(Y.cpu().numpy())

          # Map indices to class names
          idx2sym = datagenerator.output_idx2sym
          predicted_classes = [idx2sym[idx] for idx in predictions]
          actual_classes = [idx2sym[idx] for idx in actual_labels]

          # Print each word with its predicted and actual class
          for (word, _), predicted_class, actual_class in zip(datagenerator.data, predicted_classes, actual_classes):
              print(f"Name: {word} | Predicted: {predicted_class} | Actual: {actual_class}")

          # Calculate and print overall accuracy
          total = len(actual_labels)
          correct = sum(p == a for p, a in zip(predicted_classes, actual_classes))
          accuracy = 100 * correct / total
          print(f"\nPrediction Accuracy: {accuracy:.2f}%")

          # Per-class accuracy
          from collections import defaultdict
          class_correct = defaultdict(int)
          class_total = defaultdict(int)

          for pred, actual in zip(predicted_classes, actual_classes):
              class_total[actual] += 1
              if pred == actual:
                  class_correct[actual] += 1

          print("\nPer-Class Accuracy:")
          for language in class_total:
              class_accuracy = 100 * class_correct[language] / class_total[language]
              print(f"{language}: {class_accuracy:.2f}%")




    def validate(self, datagenerator, batch_size, device='cpu'):
        self.eval()
        batch_losses, batch_accuracies, batch_sizes = [], [], []

        device = torch.device(device)
        loss_fn = nn.CrossEntropyLoss()

        for seqX, seqY in datagenerator.generate_batches(batch_size):
            X = seqX.to(device)
            Y = torch.tensor(seqY, dtype=torch.long).to(device)

            with torch.no_grad():
                Yhat = self.forward(X)
                loss = loss_fn(Yhat, Y)
                Ypred = torch.argmax(Yhat, dim=1)
                acc = (Ypred == Y).sum().item()

                batch_losses.append(loss.item())
                batch_accuracies.append(acc)
                batch_sizes.append(len(Y))

        valid_loss = sum(batch_losses) / len(batch_losses)
        valid_accuracy = sum(batch_accuracies) / sum(batch_sizes) * 100
        return valid_loss, valid_accuracy

# %% [markdown]
# Main program. You are expected to search for hyperparameters:

# %%
train_data_path = 'name2lang.train'
valid_data_path = 'name2lang.valid'

traing = DataGenerator(train_data_path)
validg = DataGenerator(valid_data_path, parentgenerator=traing)

# %%
#hyperparameters testing
window_size = 4
char_embedding_size = 64
word_embedding_size = 512

model = LanguageIdentifier(traing, window_size, char_embedding_size, word_embedding_size)

# %%
#training param
epochs = 25
batch_size = 256
learning_rate = 0.001
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Train the model
model.train_model(traing, validg, epochs, batch_size, device=device, learning_rate=learning_rate)
# Out:
# Epoch [1/25], Loss: 3.3537, Validation Loss: 2.1296, Validation Acc: 45.96%
# Epoch [2/25], Loss: 1.9843, Validation Loss: 1.8318, Validation Acc: 47.24%
# Epoch [3/25], Loss: 1.7479, Validation Loss: 1.5089, Validation Acc: 56.26%
# Epoch [4/25], Loss: 1.4382, Validation Loss: 1.3985, Validation Acc: 57.96%
# Epoch [5/25], Loss: 1.3001, Validation Loss: 1.3371, Validation Acc: 59.35%
# Epoch [6/25], Loss: 1.2124, Validation Loss: 1.2717, Validation Acc: 60.59%
# Epoch [7/25], Loss: 1.1383, Validation Loss: 1.2096, Validation Acc: 63.21%
# Epoch [8/25], Loss: 1.0739, Validation Loss: 1.1476, Validation Acc: 65.12%
# Epoch [9/25], Loss: 1.0152, Validation Loss: 1.0922, Validation Acc: 67.34%
# Epoch [10/25], Loss: 0.9599, Validation Loss: 1.0428, Validation Acc: 69.29%
# Epoch [11/25], Loss: 0.9101, Validation Loss: 1.0014, Validation Acc: 70.53%
# Epoch [12/25], Loss: 0.8655, Validation Loss: 0.9651, Validation Acc: 71.92%
# Epoch [13/25], Loss: 0.8230, Validation Loss: 0.9304, Validation Acc: 72.85%
# Epoch [14/25], Loss: 0.7831, Validation Loss: 0.9045, Validation Acc: 74.45%
# Epoch [15/25], Loss: 0.7466, Validation Loss: 0.8805, Validation Acc: 75.63%
# Epoch [16/25], Loss: 0.7120, Validation Loss: 0.8609, Validation Acc: 76.25%
# Epoch [17/25], Loss: 0.6784, Validation Loss: 0.8442, Validation Acc: 76.82%
# Epoch [18/25], Loss: 0.6464, Validation Loss: 0.8286, Validation Acc: 77.38%
# Epoch [19/25], Loss: 0.6163, Validation Loss: 0.8176, Validation Acc: 77.74%
# Epoch [20/25], Loss: 0.5868, Validation Loss: 0.8051, Validation Acc: 78.41%
# Epoch [21/25], Loss: 0.5585, Validation Loss: 0.7951, Validation Acc: 78.57%
# Epoch [22/25], Loss: 0.5313, Validation Loss: 0.7873, Validation Acc: 78.72%
# Epoch [23/25], Loss: 0.5053, Validation Loss: 0.7789, Validation Acc: 79.03%
# Epoch [24/25], Loss: 0.4790, Validation Loss: 0.7731, Validation Acc: 79.19%
# Epoch [25/25], Loss: 0.4549, Validation Loss: 0.7715, Validation Acc: 79.34%

# %% [markdown]
# The model reached a validation accuracy of around 80%, which is quite good.
#
# -> early stopping effectively prevented overfitting, ensuring that the model maintained generalization performance without unnecessary training.

# %%
# Predict on validation data
print("\nPredictions on validation data:")
model.predict(validg, batch_size, device=device)
# Out:
# Predictions on validation data:
# Name: Barros | Predicted: Greek | Actual: Portuguese
# Name: Campos | Predicted: Greek | Actual: Portuguese
# Name: D'cruz | Predicted: Spanish | Actual: Portuguese
# Name: Henriques | Predicted: Russian | Actual: Portuguese
# Name: Machado | Predicted: Russian | Actual: Portuguese
# Name: Silva | Predicted: English | Actual: Portuguese
# Name: Torres | Predicted: English | Actual: Portuguese
# Name: Ahearn | Predicted: English | Actual: Irish
# Name: Aonghus | Predicted: Russian | Actual: Irish
# Name: Brady | Predicted: English | Actual: Irish
# Name: Cearbhall | Predicted: English | Actual: Irish
# Name: Flann | Predicted: English | Actual: Irish
# Name: Kavanagh | Predicted: Russian | Actual: Irish
# Name: Maguire | Predicted: Russian | Actual: Irish
# Name: Mcmahon | Predicted: English | Actual: Irish
# Name: Mcneil | Predicted: English | Actual: Irish
# Name: Monahan | Predicted: Russian | Actual: Irish
# Name: Muirchertach | Predicted: Russian | Actual: Irish
# Name: Mullen | Predicted: English | Actual: Irish
# Name: O'Connell | Predicted: Irish | Actual: Irish
# Name: O'Grady | Predicted: Irish | Actual: Irish
# Name: O'Hara | Predicted: Japanese | Actual: Irish
# Name: O'Mahony | Predicted: Irish | Actual: Irish
# Name: Rory | Predicted: English | Actual: Irish
# Name: Shannon | Predicted: Russian | Actual: Irish
# Name: Sioda | Predicted: Japanese | Actual: Irish
# Name: Tadhgan | Predicted: Russian | Actual: Irish
# Name: Abel | Predicted: Russian | Actual: Spanish
# Name: Agramunt | Predicted: Russian | Actual: Spanish
# Name: Aldana | Predicted: Italian | Actual: Spanish
# Name: Alfaro | Predicted: Italian | Actual: Spanish
# Name: Aquino | Predicted: Italian | Actual: Spanish
# Name: Arena | Predicted: Italian | Actual: Spanish
# Name: Blanco | Predicted: Italian | Actual: Spanish
# Name: Bustos | Predicted: English | Actual: Spanish
# Name: Cardona | Predicted: Italian | Actual: Spanish
# Name: Castellano | Predicted: Italian | Actual: Spanish
# Name: Del olmo | Predicted: Russian | Actual: Spanish
# Name: Etxeberria | Predicted: Russian | Actual: Spanish
# Name: Garrastazu | Predicted: Russian | Actual: Spanish
# Name: Hierro | Predicted: Italian | Actual: Spanish
# Name: Loyola | Predicted: Russian | Actual: Spanish
# Name: Maradona | Predicted: Japanese | Actual: Spanish
# Name: Mas | Predicted: English | Actual: Spanish
# Name: Nieves | Predicted: English | Actual: Spanish
# Name: Ortega | Predicted: English | Actual: Spanish
# Name: Pelaez | Predicted: Spanish | Actual: Spanish
# Name: Robles | Predicted: English | Actual: Spanish
# Name: Roldan | Predicted: English | Actual: Spanish
# Name: Suero | Predicted: Italian | Actual: Spanish
# Name: Tomas | Predicted: Arabic | Actual: Spanish
# Name: Torres | Predicted: English | Actual: Spanish
# Name: Tos | Predicted: Russian | Actual: Spanish
# Name: Ubina | Predicted: Japanese | Actual: Spanish
# Name: Urena | Predicted: Italian | Actual: Spanish
# Name: Valdez | Predicted: Russian | Actual: Spanish
# Name: Varela | Predicted: Spanish | Actual: Spanish
# Name: Vasquez | Predicted: Spanish | Actual: Spanish
# Name: Villa | Predicted: Russian | Actual: Spanish
# Name: Villaverde | Predicted: Russian | Actual: Spanish
# Name: Zavala | Predicted: Russian | Actual: Spanish
# Name: Pham | Predicted: English | Actual: Vietnamese
# Name: Vu | Predicted: Russian | Actual: Vietnamese
# Name: Ho | Predicted: Korean | Actual: Vietnamese
# Name: Banh | Predicted: Russian | Actual: Vietnamese
# Name: Dinh | Predicted: Russian | Actual: Vietnamese
# Name: Kieu | Predicted: Japanese | Actual: Vietnamese
# Name: La | Predicted: Vietnamese | Actual: Vietnamese
# Name: Pho | Predicted: Korean | Actual: Vietnamese
# Name: Sai | Predicted: Arabic | Actual: Vietnamese
# Name: Duan | Predicted: English | Actual: Chinese
# Name: Feng | Predicted: English | Actual: Chinese
# Name: Gong | Predicted: English | Actual: Chinese
# Name: Guo | Predicted: Russian | Actual: Chinese
# Name: Hew | Predicted: English | Actual: Chinese
# Name: Hong | Predicted: Korean | Actual: Chinese
# Name: Kau | Predicted: German | Actual: Chinese
# Name: Khu | Predicted: Korean | Actual: Chinese
# Name: Kwong | Predicted: Korean | Actual: Chinese
# Name: Loh | Predicted: Russian | Actual: Chinese
# Name: Que | Predicted: English | Actual: Chinese
# Name: See  | Predicted: Korean | Actual: Chinese
# Name: Shen | Predicted: Russian | Actual: Chinese
# Name: Shuai | Predicted: Japanese | Actual: Chinese
# Name: Tow | Predicted: English | Actual: Chinese
# Name: Zhang | Predicted: Russian | Actual: Chinese
# Name: Juan | Predicted: Russian | Actual: Chinese
# Name: Liang | Predicted: English | Actual: Chinese
# Name: Alexandropoulos | Predicted: English | Actual: Greek
# Name: Angelopoulos | Predicted: Greek | Actual: Greek
# Name: Antoniadis | Predicted: Russian | Actual: Greek
# Name: Comino | Predicted: Italian | Actual: Greek
# Name: Close | Predicted: Greek | Actual: Greek
# Name: Close | Predicted: Greek | Actual: Greek
# Name: Egonidis | Predicted: Russian | Actual: Greek
# Name: Giannakopoulos | Predicted: Greek | Actual: Greek
# Name: Hagias | Predicted: Russian | Actual: Greek
# Name: Karahalios | Predicted: Russian | Actual: Greek
# Name: Konstantatos | Predicted: English | Actual: Greek
# Name: Kotsiopoulos | Predicted: Greek | Actual: Greek
# Name: Matsoukis | Predicted: Greek | Actual: Greek
# Name: Paraskos | Predicted: Greek | Actual: Greek
# Name: Patrianakos | Predicted: Greek | Actual: Greek
# Name: Patselas | Predicted: Russian | Actual: Greek
# Name: Phocas | Predicted: English | Actual: Greek
# Name: Poniros | Predicted: Greek | Actual: Greek
# Name: Stamatelos | Predicted: Greek | Actual: Greek
# Name: Tselios | Predicted: Greek | Actual: Greek
# Name: Antonowitz | Predicted: Russian | Actual: Czech
# Name: Bartonova | Predicted: Russian | Actual: Czech
# Name: Blahut | Predicted: Russian | Actual: Czech
# Name: Blazek | Predicted: Russian | Actual: Czech
# Name: Brousil | Predicted: Russian | Actual: Czech
# Name: Bruckner | Predicted: English | Actual: Czech
# Name: Buchta | Predicted: Russian | Actual: Czech
# Name: Cermak | Predicted: Russian | Actual: Czech
# Name: Cerny | Predicted: Russian | Actual: Czech
# Name: Chemlik | Predicted: Russian | Actual: Czech
# Name: Chromy | Predicted: Russian | Actual: Czech
# Name: Cihak | Predicted: Russian | Actual: Czech
# Name: Cober | Predicted: English | Actual: Czech
# Name: Czabal | Predicted: Russian | Actual: Czech
# Name: Demko | Predicted: Russian | Actual: Czech
# Name: Fremut | Predicted: Russian | Actual: Czech
# Name: Gabrisova | Predicted: Russian | Actual: Czech
# Name: Gavalok | Predicted: Russian | Actual: Czech
# Name: Hanzlik | Predicted: Russian | Actual: Czech
# Name: Hartl | Predicted: English | Actual: Czech
# Name: Heidl | Predicted: English | Actual: Czech
# Name: Hiorvst | Predicted: Russian | Actual: Czech
# Name: Jaluvka | Predicted: Russian | Actual: Czech
# Name: Jirovy | Predicted: Russian | Actual: Czech
# Name: Kocian | Predicted: English | Actual: Czech
# Name: Kremlicka | Predicted: Czech | Actual: Czech
# Name: Kriz | Predicted: Czech | Actual: Czech
# Name: Kucharova | Predicted: Czech | Actual: Czech
# Name: Kofel | Predicted: German | Actual: Czech
# Name: Loskot | Predicted: Russian | Actual: Czech
# Name: Malecha | Predicted: Czech | Actual: Czech
# Name: Matocha | Predicted: Russian | Actual: Czech
# Name: MaxaB | Predicted: Russian | Actual: Czech
# Name: Navara | Predicted: Japanese | Actual: Czech
# Name: Nemecek | Predicted: Czech | Actual: Czech
# Name: Nowak | Predicted: Polish | Actual: Czech
# Name: Opp | Predicted: English | Actual: Czech
# Name: Pfeifer | Predicted: German | Actual: Czech
# Name: Pokorny | Predicted: Russian | Actual: Czech
# Name: Pretsch | Predicted: Russian | Actual: Czech
# Name: Psik | Predicted: Russian | Actual: Czech
# Name: Rafaj | Predicted: Russian | Actual: Czech
# Name: Ruzicka | Predicted: Polish | Actual: Czech
# Name: Rypka | Predicted: Russian | Actual: Czech
# Name: Satorie | Predicted: Japanese | Actual: Czech
# Name: Savchak | Predicted: Russian | Actual: Czech
# Name: Serak | Predicted: Czech | Actual: Czech
# Name: Slepicka | Predicted: Czech | Actual: Czech
# Name: Slivka | Predicted: Russian | Actual: Czech
# Name: Soucek | Predicted: Czech | Actual: Czech
# Name: Srda | Predicted: English | Actual: Czech
# Name: Steinborn | Predicted: Russian | Actual: Czech
# Name: Stramba | Predicted: Russian | Actual: Czech
# Name: Suchanka | Predicted: Czech | Actual: Czech
# Name: Svoboda | Predicted: Japanese | Actual: Czech
# Name: Till | Predicted: English | Actual: Czech
# Name: Timpe | Predicted: English | Actual: Czech
# Name: Vrazel | Predicted: Russian | Actual: Czech
# Name: Weineltk | Predicted: Russian | Actual: Czech
# Name: Wondracek | Predicted: Czech | Actual: Czech
# Name: Zaruba | Predicted: Russian | Actual: Czech
# Name: Zwolenksy | Predicted: Russian | Actual: Czech
# Name: Agthoven | Predicted: Russian | Actual: Dutch
# Name: Alst | Predicted: English | Actual: Dutch
# Name: Assen | Predicted: English | Actual: Dutch
# Name: Ven | Predicted: Russian | Actual: Dutch
# Name: Venn | Predicted: English | Actual: Dutch
# Name: Haenraets | Predicted: Russian | Actual: Dutch
# Name: Hautum | Predicted: Russian | Actual: Dutch
# Name: Houtum | Predicted: Dutch | Actual: Dutch
# Name: Karl | Predicted: English | Actual: Dutch
# Name: Klein | Predicted: English | Actual: Dutch
# Name: Klerk | Predicted: Dutch | Actual: Dutch
# Name: Klerken | Predicted: Dutch | Actual: Dutch
# Name: Kloeter | Predicted: English | Actual: Dutch
# Name: Kuijpers | Predicted: Dutch | Actual: Dutch
# Name: Kuiper | Predicted: English | Actual: Dutch
# Name: Marquerink | Predicted: Russian | Actual: Dutch
# Name: Meeuweszen | Predicted: Dutch | Actual: Dutch
# Name: Mohren | Predicted: Russian | Actual: Dutch
# Name: Rietveld | Predicted: Russian | Actual: Dutch
# Name: Rompaey | Predicted: English | Actual: Dutch
# Name: Samson | Predicted: English | Actual: Dutch
# Name: Schneiders | Predicted: Dutch | Actual: Dutch
# Name: Schoorel | Predicted: Dutch | Actual: Dutch
# Name: Snell | Predicted: English | Actual: Dutch
# Name: Snyder | Predicted: English | Actual: Dutch
# Name: Spijker | Predicted: Dutch | Actual: Dutch
# Name: Aoki | Predicted: Japanese | Actual: Japanese
# Name: Asano | Predicted: Italian | Actual: Japanese
# Name: Asanuma | Predicted: Japanese | Actual: Japanese
# Name: Ayabito | Predicted: Japanese | Actual: Japanese
# Name: Daishi | Predicted: Japanese | Actual: Japanese
# Name: Eguchi | Predicted: Japanese | Actual: Japanese
# Name: Fujioka | Predicted: Japanese | Actual: Japanese
# Name: Fujishima | Predicted: Japanese | Actual: Japanese
# Name: Fukayama | Predicted: Japanese | Actual: Japanese
# Name: Fukushima | Predicted: Japanese | Actual: Japanese
# Name: Fumihiko | Predicted: Russian | Actual: Japanese
# Name: Fuschida | Predicted: Russian | Actual: Japanese
# Name: Fuwa | Predicted: English | Actual: Japanese
# Name: Handa | Predicted: Arabic | Actual: Japanese
# Name: Hasimoto | Predicted: Japanese | Actual: Japanese
# Name: Hayakawa | Predicted: Japanese | Actual: Japanese
# Name: Hida | Predicted: Japanese | Actual: Japanese
# Name: Hirata | Predicted: Japanese | Actual: Japanese
# Name: Hiroyuki | Predicted: Russian | Actual: Japanese
# Name: Ichisada | Predicted: Japanese | Actual: Japanese
# Name: Ienari | Predicted: Japanese | Actual: Japanese
# Name: Imai | Predicted: Japanese | Actual: Japanese
# Name: Irie | Predicted: English | Actual: Japanese
# Name: Itagaki | Predicted: Japanese | Actual: Japanese
# Name: Ito | Predicted: Japanese | Actual: Japanese
# Name: Iwasa | Predicted: Japanese | Actual: Japanese
# Name: Kahae | Predicted: Arabic | Actual: Japanese
# Name: Kahaya | Predicted: Russian | Actual: Japanese
# Name: Kanegawa | Predicted: Japanese | Actual: Japanese
# Name: Kasai | Predicted: Japanese | Actual: Japanese
# Name: Katsukawa | Predicted: Japanese | Actual: Japanese
# Name: Kihara | Predicted: Japanese | Actual: Japanese
# Name: Kikkawa | Predicted: Japanese | Actual: Japanese
# Name: Kikutake | Predicted: Japanese | Actual: Japanese
# Name: Kimura | Predicted: Japanese | Actual: Japanese
# Name: Ko | Predicted: Korean | Actual: Japanese
# Name: Konda | Predicted: English | Actual: Japanese
# Name: Kurata | Predicted: Japanese | Actual: Japanese
# Name: Maeda | Predicted: Japanese | Actual: Japanese
# Name: Marubeni | Predicted: Russian | Actual: Japanese
# Name: Maruya | Predicted: Russian | Actual: Japanese
# Name: Mashita | Predicted: Japanese | Actual: Japanese
# Name: Matsura | Predicted: Japanese | Actual: Japanese
# Name: Matsuzawa | Predicted: Japanese | Actual: Japanese
# Name: Miyamoto | Predicted: Japanese | Actual: Japanese
# Name: Mizutani | Predicted: Japanese | Actual: Japanese
# Name: Monomonoi | Predicted: Japanese | Actual: Japanese
# Name: Morimoto | Predicted: Japanese | Actual: Japanese
# Name: Munakata | Predicted: Japanese | Actual: Japanese
# Name: Muraguchi | Predicted: Japanese | Actual: Japanese
# Name: Mutsu | Predicted: Russian | Actual: Japanese
# Name: Nagahama | Predicted: Japanese | Actual: Japanese
# Name: Nagano | Predicted: Italian | Actual: Japanese
# Name: Nakamura | Predicted: Japanese | Actual: Japanese
# Name: Nakanoi | Predicted: Japanese | Actual: Japanese
# Name: Nemoto | Predicted: Japanese | Actual: Japanese
# Name: Nijo | Predicted: Japanese | Actual: Japanese
# Name: Nogushi | Predicted: Japanese | Actual: Japanese
# Name: Okabe | Predicted: Japanese | Actual: Japanese
# Name: Okamoto | Predicted: Japanese | Actual: Japanese
# Name: Okasawa | Predicted: Japanese | Actual: Japanese
# Name: Okuda | Predicted: Japanese | Actual: Japanese
# Name: Otsuka | Predicted: Japanese | Actual: Japanese
# Name: Sada | Predicted: Japanese | Actual: Japanese
# Name: Satoh | Predicted: Japanese | Actual: Japanese
# Name: Shibasawa | Predicted: Japanese | Actual: Japanese
# Name: Shigi | Predicted: Japanese | Actual: Japanese
# Name: Shimanouchi | Predicted: Japanese | Actual: Japanese
# Name: Shimon | Predicted: Russian | Actual: Japanese
# Name: Shionoya | Predicted: Japanese | Actual: Japanese
# Name: Shiraishi | Predicted: Japanese | Actual: Japanese
# Name: Shunsen | Predicted: Russian | Actual: Japanese
# Name: Soseki | Predicted: Japanese | Actual: Japanese
# Name: Suenami | Predicted: Japanese | Actual: Japanese
# Name: Sugitani | Predicted: Japanese | Actual: Japanese
# Name: Sugiyama | Predicted: Japanese | Actual: Japanese
# Name: Sumitimo | Predicted: Japanese | Actual: Japanese
# Name: Taguchi | Predicted: Japanese | Actual: Japanese
# Name: Taira | Predicted: Japanese | Actual: Japanese
# Name: Takahama | Predicted: Japanese | Actual: Japanese
# Name: Takamura | Predicted: Japanese | Actual: Japanese
# Name: Takara | Predicted: Japanese | Actual: Japanese
# Name: Takemitsu | Predicted: Japanese | Actual: Japanese
# Name: Taku | Predicted: Russian | Actual: Japanese
# Name: Tarumi | Predicted: Japanese | Actual: Japanese
# Name: Tomika | Predicted: Japanese | Actual: Japanese
# Name: Tomonaga | Predicted: Japanese | Actual: Japanese
# Name: Toshishai | Predicted: Japanese | Actual: Japanese
# Name: Uchiyama | Predicted: Japanese | Actual: Japanese
# Name: Umari | Predicted: Arabic | Actual: Japanese
# Name: Wakatsuki | Predicted: Russian | Actual: Japanese
# Name: Yamakawa | Predicted: Japanese | Actual: Japanese
# Name: Yamura | Predicted: Japanese | Actual: Japanese
# Name: Yasuhiro | Predicted: Russian | Actual: Japanese
# Name: Yasui | Predicted: Japanese | Actual: Japanese
# Name: Yoshifumi | Predicted: Japanese | Actual: Japanese
# Name: Armistead | Predicted: English | Actual: French
# Name: Baudin | Predicted: Russian | Actual: French
# Name: Beaulieu | Predicted: Italian | Actual: French
# Name: Bertrand | Predicted: English | Actual: French
# Name: Bissette | Predicted: English | Actual: French
# Name: Blanc | Predicted: English | Actual: French
# Name: Bonfils | Predicted: English | Actual: French
# Name: Charbonneau | Predicted: English | Actual: French
# Name: Charpentier | Predicted: English | Actual: French
# Name: Chevalier | Predicted: Russian | Actual: French
# Name: Cote | Predicted: English | Actual: French
# Name: Couture | Predicted: French | Actual: French
# Name: Delacroix | Predicted: Italian | Actual: French
# Name: Desrochers | Predicted: English | Actual: French
# Name: Emile | Predicted: English | Actual: French
# Name: Fabre | Predicted: English | Actual: French
# Name: Lamar | Predicted: English | Actual: French
# Name: Lane | Predicted: English | Actual: French
# Name: Legrand | Predicted: English | Actual: French
# Name: Lemieux | Predicted: French | Actual: French
# Name: Leveque | Predicted: French | Actual: French
# Name: Mathieu | Predicted: Japanese | Actual: French
# Name: Mercier | Predicted: English | Actual: French
# Name: Merle | Predicted: English | Actual: French
# Name: Page | Predicted: English | Actual: French
# Name: Parris | Predicted: English | Actual: French
# Name: Pettigrew | Predicted: English | Actual: French
# Name: Roche | Predicted: English | Actual: French
# Name: Salomon | Predicted: Polish | Actual: French
# Name: Samson | Predicted: English | Actual: French
# Name: Sauvageot | Predicted: French | Actual: French
# Name: Sauveterre | Predicted: French | Actual: French
# Name: Sergeant | Predicted: English | Actual: French
# Name: Traverse | Predicted: English | Actual: French
# Name: Abel | Predicted: Russian | Actual: German
# Name: Abt | Predicted: Russian | Actual: German
# Name: Bayer | Predicted: Arabic | Actual: German
# Name: Berg | Predicted: German | Actual: German
# Name: Biermann | Predicted: Russian | Actual: German
# Name: Brand | Predicted: English | Actual: German
# Name: Brune | Predicted: German | Actual: German
# Name: Chevrolet | Predicted: Russian | Actual: German
# Name: Cline | Predicted: English | Actual: German
# Name: Diefenbach | Predicted: Russian | Actual: German
# Name: Dieter | Predicted: English | Actual: German
# Name: Fabel | Predicted: Russian | Actual: German
# Name: Farber | Predicted: English | Actual: German
# Name: Feigenbaum | Predicted: Russian | Actual: German
# Name: Frank | Predicted: Russian | Actual: German
# Name: Gartner | Predicted: English | Actual: German
# Name: Geisler | Predicted: English | Actual: German
# Name: Gerhard | Predicted: English | Actual: German
# Name: Giese | Predicted: English | Actual: German
# Name: Gorman | Predicted: Russian | Actual: German
# Name: Graner | Predicted: English | Actual: German
# Name: Gunther | Predicted: English | Actual: German
# Name: Halle | Predicted: English | Actual: German
# Name: Hartmann | Predicted: Russian | Actual: German
# Name: Hase | Predicted: Arabic | Actual: German
# Name: Hasek | Predicted: Czech | Actual: German
# Name: Hirsch | Predicted: German | Actual: German
# Name: Hochberg | Predicted: German | Actual: German
# Name: Hofmann | Predicted: Russian | Actual: German
# Name: Hofmeister | Predicted: German | Actual: German
# Name: Holzer | Predicted: German | Actual: German
# Name: Hoover | Predicted: English | Actual: German
# Name: Karl | Predicted: English | Actual: German
# Name: Kaufer | Predicted: German | Actual: German
# Name: Kaufer | Predicted: German | Actual: German
# Name: Knopf | Predicted: German | Actual: German
# Name: Kohl | Predicted: German | Actual: German
# Name: Kruckel | Predicted: English | Actual: German
# Name: Kruse | Predicted: German | Actual: German
# Name: Luther | Predicted: English | Actual: German
# Name: Meier | Predicted: German | Actual: German
# Name: Metz | Predicted: German | Actual: German
# Name: Michel | Predicted: Russian | Actual: German
# Name: Nussbaum | Predicted: Russian | Actual: German
# Name: Nussenbaum | Predicted: Russian | Actual: German
# Name: Oelberg | Predicted: German | Actual: German
# Name: Oliver | Predicted: English | Actual: German
# Name: Prinz | Predicted: Russian | Actual: German
# Name: Reier | Predicted: English | Actual: German
# Name: Reiter | Predicted: Russian | Actual: German
# Name: Rose | Predicted: English | Actual: German
# Name: Rosenberg | Predicted: English | Actual: German
# Name: Sauber | Predicted: German | Actual: German
# Name: Schneider | Predicted: Dutch | Actual: German
# Name: Schroder | Predicted: German | Actual: German
# Name: Schroeder | Predicted: English | Actual: German
# Name: Schubert | Predicted: German | Actual: German
# Name: Schuchardt | Predicted: German | Actual: German
# Name: Schuler | Predicted: German | Actual: German
# Name: Senft | Predicted: German | Actual: German
# Name: Siekert | Predicted: English | Actual: German
# Name: Stieber | Predicted: English | Actual: German
# Name: Swango | Predicted: Russian | Actual: German
# Name: Tanzer | Predicted: Russian | Actual: German
# Name: Tobias | Predicted: Russian | Actual: German
# Name: Tritten | Predicted: English | Actual: German
# Name: Unterbrink | Predicted: Russian | Actual: German
# Name: Volk | Predicted: Russian | Actual: German
# Name: Voll | Predicted: English | Actual: German
# Name: Von essen | Predicted: German | Actual: German
# Name: Walkenhorst | Predicted: English | Actual: German
# Name: Walther | Predicted: English | Actual: German
# Name: Waltz | Predicted: German | Actual: German
# Name: Wang | Predicted: Korean | Actual: German
# Name: Weiner | Predicted: German | Actual: German
# Name: Wernher | Predicted: English | Actual: German
# Name: Wetterman | Predicted: English | Actual: German
# Name: Winther | Predicted: English | Actual: German
# Name: Worner | Predicted: English | Actual: German
# Name: Taylor | Predicted: English | Actual: Scottish
# Name: Clark | Predicted: English | Actual: Scottish
# Name: Hamilton | Predicted: English | Actual: Scottish
# Name: Grant | Predicted: English | Actual: Scottish
# Name: Mclean | Predicted: English | Actual: Scottish
# Name: Williamson | Predicted: English | Actual: Scottish
# Name: Dickson | Predicted: English | Actual: Scottish
# Name: Addinall | Predicted: English | Actual: English
# Name: Adlam | Predicted: English | Actual: English
# Name: Aitchison | Predicted: English | Actual: English
# Name: Alderson | Predicted: English | Actual: English
# Name: Alexnader | Predicted: English | Actual: English
# Name: Allan | Predicted: English | Actual: English
# Name: Allen | Predicted: English | Actual: English
# Name: Amos | Predicted: Greek | Actual: English
# Name: Antic | Predicted: English | Actual: English
# Name: Archer | Predicted: English | Actual: English
# Name: Ardern | Predicted: English | Actual: English
# Name: Arnall | Predicted: English | Actual: English
# Name: Arthur | Predicted: Russian | Actual: English
# Name: Ashbridge | Predicted: English | Actual: English
# Name: Aspinall | Predicted: English | Actual: English
# Name: Atterbury | Predicted: English | Actual: English
# Name: Attewell | Predicted: English | Actual: English
# Name: Auton | Predicted: English | Actual: English
# Name: Axon | Predicted: English | Actual: English
# Name: Aylward | Predicted: English | Actual: English
# Name: Ayres | Predicted: English | Actual: English
# Name: Bain | Predicted: Russian | Actual: English
# Name: Bannister | Predicted: English | Actual: English
# Name: Barnard | Predicted: English | Actual: English
# Name: Barnett | Predicted: English | Actual: English
# Name: Bartlett | Predicted: English | Actual: English
# Name: Barton | Predicted: English | Actual: English
# Name: Bassett | Predicted: English | Actual: English
# Name: Batchelor | Predicted: Russian | Actual: English
# Name: Baxter | Predicted: Russian | Actual: English
# Name: Beamish | Predicted: Russian | Actual: English
# Name: Beer | Predicted: English | Actual: English
# Name: Bell | Predicted: English | Actual: English
# Name: Binnington | Predicted: English | Actual: English
# Name: Blakey | Predicted: English | Actual: English
# Name: Bond | Predicted: English | Actual: English
# Name: Bristow | Predicted: English | Actual: English
# Name: Bryan | Predicted: Russian | Actual: English
# Name: Budd | Predicted: English | Actual: English
# Name: Burland | Predicted: English | Actual: English
# Name: Burn | Predicted: English | Actual: English
# Name: Casey | Predicted: English | Actual: English
# Name: Childs | Predicted: English | Actual: English
# Name: Clifton | Predicted: English | Actual: English
# Name: Coffey | Predicted: English | Actual: English
# Name: Cohen | Predicted: Russian | Actual: English
# Name: Cole | Predicted: English | Actual: English
# Name: Colley | Predicted: English | Actual: English
# Name: Copeland | Predicted: English | Actual: English
# Name: Copley | Predicted: English | Actual: English
# Name: Corr | Predicted: English | Actual: English
# Name: Costa | Predicted: Italian | Actual: English
# Name: Cotter | Predicted: English | Actual: English
# Name: Cotterill | Predicted: English | Actual: English
# Name: Cowie | Predicted: English | Actual: English
# Name: Creasey | Predicted: English | Actual: English
# Name: Crocker | Predicted: English | Actual: English
# Name: Cronin | Predicted: Russian | Actual: English
# Name: Crowther | Predicted: English | Actual: English
# Name: Danks | Predicted: English | Actual: English
# Name: Darbyshire | Predicted: Arabic | Actual: English
# Name: Davies | Predicted: English | Actual: English
# Name: Dawe | Predicted: English | Actual: English
# Name: Dawkins | Predicted: English | Actual: English
# Name: Deighton | Predicted: English | Actual: English
# Name: Dennis | Predicted: English | Actual: English
# Name: Dexter | Predicted: English | Actual: English
# Name: Dimmock | Predicted: English | Actual: English
# Name: Dobbins | Predicted: English | Actual: English
# Name: Dodson | Predicted: English | Actual: English
# Name: Dolton | Predicted: English | Actual: English
# Name: Donnelly | Predicted: English | Actual: English
# Name: Doolin | Predicted: Russian | Actual: English
# Name: Douglas | Predicted: English | Actual: English
# Name: Drysdale | Predicted: English | Actual: English
# Name: Duckworth | Predicted: English | Actual: English
# Name: Dundon | Predicted: English | Actual: English
# Name: Dunn | Predicted: English | Actual: English
# Name: Duval | Predicted: Russian | Actual: English
# Name: Eastaway | Predicted: English | Actual: English
# Name: Eccles | Predicted: English | Actual: English
# Name: Edney | Predicted: English | Actual: English
# Name: Ellerby | Predicted: English | Actual: English
# Name: Ellershaw | Predicted: English | Actual: English
# Name: Elvins | Predicted: Russian | Actual: English
# Name: Emmerson | Predicted: English | Actual: English
# Name: Emmott | Predicted: English | Actual: English
# Name: Etheridge | Predicted: English | Actual: English
# Name: Etherton | Predicted: English | Actual: English
# Name: Ettrick | Predicted: English | Actual: English
# Name: Evison | Predicted: Russian | Actual: English
# Name: Exley | Predicted: English | Actual: English
# Name: Fagan | Predicted: Russian | Actual: English
# Name: Fairchild | Predicted: English | Actual: English
# Name: Farr | Predicted: English | Actual: English
# Name: Farrelly | Predicted: English | Actual: English
# Name: Farrier | Predicted: English | Actual: English
# Name: Ferdinand | Predicted: English | Actual: English
# Name: Fields | Predicted: English | Actual: English
# Name: Fitzsimmons | Predicted: Italian | Actual: English
# Name: Fleetwood | Predicted: English | Actual: English
# Name: Flower | Predicted: English | Actual: English
# Name: Fogg | Predicted: English | Actual: English
# Name: Forsythe | Predicted: English | Actual: English
# Name: Freedman | Predicted: English | Actual: English
# Name: Friend | Predicted: English | Actual: English
# Name: Frith | Predicted: English | Actual: English
# Name: Froy | Predicted: English | Actual: English
# Name: Fulleron | Predicted: English | Actual: English
# Name: Gadsden | Predicted: Russian | Actual: English
# Name: Gall | Predicted: English | Actual: English
# Name: Gamble | Predicted: English | Actual: English
# Name: Gammer | Predicted: English | Actual: English
# Name: Garvey | Predicted: English | Actual: English
# Name: Gaudin | Predicted: Russian | Actual: English
# Name: Gavin | Predicted: Russian | Actual: English
# Name: Geaney | Predicted: English | Actual: English
# Name: Geeson | Predicted: English | Actual: English
# Name: Gifford | Predicted: English | Actual: English
# Name: Giles | Predicted: English | Actual: English
# Name: Gledhill | Predicted: English | Actual: English
# Name: Glew | Predicted: English | Actual: English
# Name: Godby | Predicted: English | Actual: English
# Name: Gonzalez | Predicted: Spanish | Actual: English
# Name: Goodall | Predicted: English | Actual: English
# Name: Goodchild | Predicted: English | Actual: English
# Name: Gowing | Predicted: English | Actual: English
# Name: Granger | Predicted: English | Actual: English
# Name: Gray | Predicted: English | Actual: English
# Name: Grayson | Predicted: Russian | Actual: English
# Name: Greenshields | Predicted: English | Actual: English
# Name: Grey | Predicted: English | Actual: English
# Name: Grimes | Predicted: English | Actual: English
# Name: Grogan | Predicted: Russian | Actual: English
# Name: Groom | Predicted: Russian | Actual: English
# Name: Grose | Predicted: Russian | Actual: English
# Name: Gunning | Predicted: Russian | Actual: English
# Name: Guthrie | Predicted: Russian | Actual: English
# Name: Gutteridge | Predicted: English | Actual: English
# Name: Hallam | Predicted: English | Actual: English
# Name: Hand | Predicted: English | Actual: English
# Name: Hannam | Predicted: English | Actual: English
# Name: Hansen | Predicted: Russian | Actual: English
# Name: Harding | Predicted: English | Actual: English
# Name: Harrison | Predicted: English | Actual: English
# Name: Hartley | Predicted: English | Actual: English
# Name: Harvey | Predicted: English | Actual: English
# Name: Hawtin | Predicted: Russian | Actual: English
# Name: Heathcote | Predicted: English | Actual: English
# Name: Heneghan | Predicted: English | Actual: English
# Name: Hewlett | Predicted: English | Actual: English
# Name: Hibbert | Predicted: Russian | Actual: English
# Name: Hickey | Predicted: English | Actual: English
# Name: Hickman | Predicted: English | Actual: English
# Name: Hindley | Predicted: English | Actual: English
# Name: Hoare | Predicted: English | Actual: English
# Name: Hodgkinson | Predicted: English | Actual: English
# Name: Hodkinson | Predicted: English | Actual: English
# Name: Holdsworth | Predicted: English | Actual: English
# Name: Howard | Predicted: English | Actual: English
# Name: Howes | Predicted: English | Actual: English
# Name: Hulme | Predicted: English | Actual: English
# Name: Hume | Predicted: English | Actual: English
# Name: Hussey | Predicted: English | Actual: English
# Name: Ibbotson | Predicted: Russian | Actual: English
# Name: Ingledew | Predicted: English | Actual: English
# Name: Inglethorpe | Predicted: English | Actual: English
# Name: Ironman | Predicted: English | Actual: English
# Name: Irvin | Predicted: Russian | Actual: English
# Name: Jennison | Predicted: English | Actual: English
# Name: Jermy | Predicted: Russian | Actual: English
# Name: Jesson | Predicted: English | Actual: English
# Name: Kavanagh | Predicted: Russian | Actual: English
# Name: Keable | Predicted: English | Actual: English
# Name: Keane | Predicted: English | Actual: English
# Name: Keighley | Predicted: English | Actual: English
# Name: Kentwood | Predicted: English | Actual: English
# Name: Kerr | Predicted: English | Actual: English
# Name: Keyte | Predicted: English | Actual: English
# Name: Kidman | Predicted: English | Actual: English
# Name: Kiely | Predicted: English | Actual: English
# Name: Kilb | Predicted: English | Actual: English
# Name: Kill | Predicted: English | Actual: English
# Name: Kilshaw | Predicted: English | Actual: English
# Name: Kingdon | Predicted: English | Actual: English
# Name: Kinrade | Predicted: English | Actual: English
# Name: Kirkbright | Predicted: English | Actual: English
# Name: Kirkby | Predicted: English | Actual: English
# Name: Kitchen | Predicted: English | Actual: English
# Name: Knab | Predicted: English | Actual: English
# Name: Knowler | Predicted: English | Actual: English
# Name: Kouma | Predicted: Arabic | Actual: English
# Name: Laing | Predicted: English | Actual: English
# Name: Lake | Predicted: English | Actual: English
# Name: Lakey | Predicted: English | Actual: English
# Name: Lawrence | Predicted: English | Actual: English
# Name: Lawson | Predicted: English | Actual: English
# Name: Lawton | Predicted: English | Actual: English
# Name: Leach | Predicted: Russian | Actual: English
# Name: Leaver | Predicted: English | Actual: English
# Name: Leckie | Predicted: English | Actual: English
# Name: Leroy | Predicted: Russian | Actual: English
# Name: Levy | Predicted: Russian | Actual: English
# Name: Lewin | Predicted: Russian | Actual: English
# Name: Lewins | Predicted: English | Actual: English
# Name: Llewellyn | Predicted: English | Actual: English
# Name: Lofthouse | Predicted: English | Actual: English
# Name: Logan | Predicted: Russian | Actual: English
# Name: Longley | Predicted: English | Actual: English
# Name: Longworth | Predicted: English | Actual: English
# Name: Loughran | Predicted: English | Actual: English
# Name: Lowis | Predicted: English | Actual: English
# Name: Lyall | Predicted: English | Actual: English
# Name: Mac | Predicted: English | Actual: English
# Name: Macfarlane | Predicted: English | Actual: English
# Name: Macleod | Predicted: English | Actual: English
# Name: Macpherson | Predicted: English | Actual: English
# Name: Maddocks | Predicted: English | Actual: English
# Name: Magee | Predicted: English | Actual: English
# Name: Malone | Predicted: English | Actual: English
# Name: Maloney | Predicted: English | Actual: English
# Name: Marshall | Predicted: English | Actual: English
# Name: Martinez | Predicted: Spanish | Actual: English
# Name: Matheson | Predicted: English | Actual: English
# Name: Mcarthur | Predicted: English | Actual: English
# Name: Mccluskey | Predicted: English | Actual: English
# Name: Mcghee | Predicted: English | Actual: English
# Name: Mcgrory | Predicted: English | Actual: English
# Name: Mcguinness | Predicted: English | Actual: English
# Name: Mclaren | Predicted: English | Actual: English
# Name: Mcnally | Predicted: English | Actual: English
# Name: Mcneil | Predicted: English | Actual: English
# Name: Mcneill | Predicted: English | Actual: English
# Name: Merritt | Predicted: English | Actual: English
# Name: Miles | Predicted: English | Actual: English
# Name: Millington | Predicted: English | Actual: English
# Name: Morrison | Predicted: English | Actual: English
# Name: Murphy | Predicted: English | Actual: English
# Name: Nanson | Predicted: English | Actual: English
# Name: Needham | Predicted: English | Actual: English
# Name: Neeson | Predicted: English | Actual: English
# Name: Neill | Predicted: English | Actual: English
# Name: Newsome | Predicted: English | Actual: English
# Name: Normington | Predicted: English | Actual: English
# Name: Northcott | Predicted: English | Actual: English
# Name: Nott | Predicted: English | Actual: English
# Name: Nutman | Predicted: Russian | Actual: English
# Name: Odling | Predicted: English | Actual: English
# Name: Odriscoll | Predicted: English | Actual: English
# Name: Oliver | Predicted: English | Actual: English
# Name: Orme | Predicted: English | Actual: English
# Name: Oswald | Predicted: English | Actual: English
# Name: Oxley | Predicted: English | Actual: English
# Name: Parish | Predicted: Russian | Actual: English
# Name: Parnell | Predicted: English | Actual: English
# Name: Parry | Predicted: English | Actual: English
# Name: Partridge | Predicted: English | Actual: English
# Name: Pattinson | Predicted: English | Actual: English
# Name: Payne | Predicted: English | Actual: English
# Name: Peach | Predicted: Russian | Actual: English
# Name: Peters | Predicted: English | Actual: English
# Name: Petersen | Predicted: English | Actual: English
# Name: Peterson | Predicted: English | Actual: English
# Name: Pick | Predicted: English | Actual: English
# Name: Pitts | Predicted: Russian | Actual: English
# Name: Plummer | Predicted: Russian | Actual: English
# Name: Pocock | Predicted: English | Actual: English
# Name: Pollock | Predicted: English | Actual: English
# Name: Potter | Predicted: English | Actual: English
# Name: Powles | Predicted: English | Actual: English
# Name: Pullen | Predicted: English | Actual: English
# Name: Purvis | Predicted: English | Actual: English
# Name: Rahman | Predicted: Russian | Actual: English
# Name: Rainford | Predicted: English | Actual: English
# Name: Ramsey | Predicted: English | Actual: English
# Name: Rawsthorne | Predicted: English | Actual: English
# Name: Reeves | Predicted: English | Actual: English
# Name: Renwick | Predicted: English | Actual: English
# Name: Reyes | Predicted: English | Actual: English
# Name: Ricci | Predicted: Italian | Actual: English
# Name: Richardson | Predicted: English | Actual: English
# Name: Ridge | Predicted: English | Actual: English
# Name: Robert | Predicted: French | Actual: English
# Name: Robotham | Predicted: English | Actual: English
# Name: Rochford | Predicted: English | Actual: English
# Name: Rodger | Predicted: English | Actual: English
# Name: Roebuck | Predicted: English | Actual: English
# Name: Rogers | Predicted: English | Actual: English
# Name: Roles | Predicted: English | Actual: English
# Name: Rook | Predicted: English | Actual: English
# Name: Ruff | Predicted: English | Actual: English
# Name: Rush | Predicted: Russian | Actual: English
# Name: Rushby | Predicted: Russian | Actual: English
# Name: Russel | Predicted: English | Actual: English
# Name: Russon | Predicted: English | Actual: English
# Name: Ryder | Predicted: English | Actual: English
# Name: Salt | Predicted: English | Actual: English
# Name: Samuel | Predicted: German | Actual: English
# Name: Seer | Predicted: German | Actual: English
# Name: Selby | Predicted: English | Actual: English
# Name: Shea | Predicted: Chinese | Actual: English
# Name: Showell | Predicted: English | Actual: English
# Name: Shuttleworth | Predicted: English | Actual: English
# Name: Simpson | Predicted: English | Actual: English
# Name: Sims | Predicted: English | Actual: English
# Name: Sisson | Predicted: English | Actual: English
# Name: Skelton | Predicted: English | Actual: English
# Name: Snell | Predicted: English | Actual: English
# Name: Southern | Predicted: English | Actual: English
# Name: Stephenson | Predicted: English | Actual: English
# Name: Sturrock | Predicted: English | Actual: English
# Name: Styles | Predicted: English | Actual: English
# Name: Swift | Predicted: English | Actual: English
# Name: Sylvester | Predicted: English | Actual: English
# Name: Tait | Predicted: Russian | Actual: English
# Name: Tapping | Predicted: English | Actual: English
# Name: Tarr | Predicted: English | Actual: English
# Name: Tarrant | Predicted: English | Actual: English
# Name: Telford | Predicted: English | Actual: English
# Name: Tempest | Predicted: English | Actual: English
# Name: Tennant | Predicted: Russian | Actual: English
# Name: Thompson | Predicted: English | Actual: English
# Name: Thornhill | Predicted: English | Actual: English
# Name: Thornton | Predicted: English | Actual: English
# Name: Tierney | Predicted: English | Actual: English
# Name: Tippins | Predicted: Russian | Actual: English
# Name: Titmuss | Predicted: Russian | Actual: English
# Name: Titterington | Predicted: English | Actual: English
# Name: Tobin | Predicted: Russian | Actual: English
# Name: Toland | Predicted: English | Actual: English
# Name: Tolley | Predicted: English | Actual: English
# Name: Tollis | Predicted: English | Actual: English
# Name: Tomas | Predicted: Arabic | Actual: English
# Name: Tomkins | Predicted: Russian | Actual: English
# Name: Tonks | Predicted: English | Actual: English
# Name: Townsley | Predicted: English | Actual: English
# Name: Trotman | Predicted: Russian | Actual: English
# Name: Tuckey | Predicted: English | Actual: English
# Name: Tuffnell | Predicted: English | Actual: English
# Name: Turton | Predicted: English | Actual: English
# Name: Twiggs | Predicted: English | Actual: English
# Name: Uddin | Predicted: Russian | Actual: English
# Name: Ullman | Predicted: English | Actual: English
# Name: Upfield | Predicted: English | Actual: English
# Name: Veasey | Predicted: Russian | Actual: English
# Name: Wade | Predicted: English | Actual: English
# Name: Wang | Predicted: Korean | Actual: English
# Name: Ware | Predicted: English | Actual: English
# Name: Wareing | Predicted: English | Actual: English
# Name: Warren | Predicted: English | Actual: English
# Name: Wellington | Predicted: English | Actual: English
# Name: Wheatcroft | Predicted: English | Actual: English
# Name: Whitaker | Predicted: Russian | Actual: English
# Name: Whitelaw | Predicted: English | Actual: English
# Name: Whittaker | Predicted: Russian | Actual: English
# Name: Widdows | Predicted: English | Actual: English
# Name: Wilcox | Predicted: English | Actual: English
# Name: Wilkshire | Predicted: Russian | Actual: English
# Name: Willis | Predicted: English | Actual: English
# Name: Wilton | Predicted: English | Actual: English
# Name: Winfer | Predicted: English | Actual: English
# Name: Wiseman | Predicted: Russian | Actual: English
# Name: Worth | Predicted: English | Actual: English
# Name: Wraight | Predicted: English | Actual: English
# Name: Yang | Predicted: Korean | Actual: English
# Name: Yates | Predicted: English | Actual: English
# Name: Youssouf | Predicted: English | Actual: English
# Name: Abakumov | Predicted: Russian | Actual: Russian
# Name: Abakushin | Predicted: Russian | Actual: Russian
# Name: Abalmasoff | Predicted: Russian | Actual: Russian
# Name: Abdildin | Predicted: Russian | Actual: Russian
# Name: Abdrakhimoff | Predicted: Russian | Actual: Russian
# Name: Abdrazakov | Predicted: Russian | Actual: Russian
# Name: Abdulbasiroff | Predicted: Russian | Actual: Russian
# Name: Abdulgapurov | Predicted: Russian | Actual: Russian
# Name: Abdurahmanov | Predicted: Russian | Actual: Russian
# Name: Abitov | Predicted: Russian | Actual: Russian
# Name: Abjalilov | Predicted: Russian | Actual: Russian
# Name: Abletsoff | Predicted: Russian | Actual: Russian
# Name: Ableuhov | Predicted: Russian | Actual: Russian
# Name: Abolikhin | Predicted: Russian | Actual: Russian
# Name: Abov | Predicted: Russian | Actual: Russian
# Name: Abrahimoff | Predicted: Russian | Actual: Russian
# Name: Abrahimov | Predicted: Russian | Actual: Russian
# Name: Abramtsev | Predicted: Russian | Actual: Russian
# Name: Abrosoff | Predicted: Russian | Actual: Russian
# Name: Abubakiroff | Predicted: Russian | Actual: Russian
# Name: Abubekerov | Predicted: Russian | Actual: Russian
# Name: Abylgaziev | Predicted: Russian | Actual: Russian
# Name: Adam | Predicted: English | Actual: Russian
# Name: Adamson | Predicted: English | Actual: Russian
# Name: Adelhanov | Predicted: Russian | Actual: Russian
# Name: Aderikhin | Predicted: Russian | Actual: Russian
# Name: Adibekov | Predicted: Russian | Actual: Russian
# Name: Adodin | Predicted: Russian | Actual: Russian
# Name: Adoduroff | Predicted: Russian | Actual: Russian
# Name: Adroff | Predicted: Russian | Actual: Russian
# Name: Adulov | Predicted: Russian | Actual: Russian
# Name: Aedonitsky | Predicted: Russian | Actual: Russian
# Name: Agabekov | Predicted: Russian | Actual: Russian
# Name: Agadjanov | Predicted: Russian | Actual: Russian
# Name: Agalaroff | Predicted: Russian | Actual: Russian
# Name: Agalov | Predicted: Russian | Actual: Russian
# Name: Agamirov | Predicted: Russian | Actual: Russian
# Name: Agamov | Predicted: Russian | Actual: Russian
# Name: Aganoff | Predicted: Russian | Actual: Russian
# Name: Agaphonov | Predicted: Russian | Actual: Russian
# Name: Agapotchkin | Predicted: Russian | Actual: Russian
# Name: Agarkov | Predicted: Russian | Actual: Russian
# Name: Agatoff | Predicted: Russian | Actual: Russian
# Name: Agranowich | Predicted: Russian | Actual: Russian
# Name: Agratin | Predicted: Russian | Actual: Russian
# Name: Agrenev | Predicted: Russian | Actual: Russian
# Name: Agutin | Predicted: Russian | Actual: Russian
# Name: Ajiganoff | Predicted: Russian | Actual: Russian
# Name: Alferov | Predicted: Russian | Actual: Russian
# Name: Alianaki | Predicted: Russian | Actual: Russian
# Name: Alianov | Predicted: Russian | Actual: Russian
# Name: Alypov | Predicted: Russian | Actual: Russian
# Name: Amelin | Predicted: Russian | Actual: Russian
# Name: Andreichev | Predicted: Russian | Actual: Russian
# Name: Andreli | Predicted: Russian | Actual: Russian
# Name: Andruhovich | Predicted: Russian | Actual: Russian
# Name: Andryuschenko | Predicted: Russian | Actual: Russian
# Name: Antopolsky | Predicted: Russian | Actual: Russian
# Name: Anufriev | Predicted: Russian | Actual: Russian
# Name: Anuriev | Predicted: Russian | Actual: Russian
# Name: Araslanov | Predicted: Russian | Actual: Russian
# Name: Artyukhin | Predicted: Russian | Actual: Russian
# Name: Astrakhansky | Predicted: Russian | Actual: Russian
# Name: Atabiev | Predicted: Russian | Actual: Russian
# Name: Atvilov | Predicted: Russian | Actual: Russian
# Name: Auerbakh | Predicted: Russian | Actual: Russian
# Name: August | Predicted: Russian | Actual: Russian
# Name: Avdakoff | Predicted: Russian | Actual: Russian
# Name: Avdeeff | Predicted: Russian | Actual: Russian
# Name: Avdievsky | Predicted: Russian | Actual: Russian
# Name: Avdulov | Predicted: Russian | Actual: Russian
# Name: Avdyushin | Predicted: Russian | Actual: Russian
# Name: Avelichev | Predicted: Russian | Actual: Russian
# Name: Averchenko | Predicted: Russian | Actual: Russian
# Name: Avgustov | Predicted: Russian | Actual: Russian
# Name: Avksentievski | Predicted: Russian | Actual: Russian
# Name: Avladeev | Predicted: Russian | Actual: Russian
# Name: Avrov | Predicted: Russian | Actual: Russian
# Name: Awaeff | Predicted: Russian | Actual: Russian
# Name: Awerkieff | Predicted: Russian | Actual: Russian
# Name: Awetisoff | Predicted: Russian | Actual: Russian
# Name: Awhadieff | Predicted: Russian | Actual: Russian
# Name: Awhimowich | Predicted: Russian | Actual: Russian
# Name: Awksentiev | Predicted: Russian | Actual: Russian
# Name: Awtonomoff | Predicted: Russian | Actual: Russian
# Name: Awtorhanoff | Predicted: Russian | Actual: Russian
# Name: Awtorkhanoff | Predicted: Russian | Actual: Russian
# Name: Awturkhanoff | Predicted: Russian | Actual: Russian
# Name: Azhinoff | Predicted: Russian | Actual: Russian
# Name: Babahanov | Predicted: Russian | Actual: Russian
# Name: Babaitsev | Predicted: Russian | Actual: Russian
# Name: Babikov | Predicted: Russian | Actual: Russian
# Name: Babiy | Predicted: Russian | Actual: Russian
# Name: Babkeev | Predicted: Russian | Actual: Russian
# Name: Bablumyan | Predicted: Russian | Actual: Russian
# Name: Baboshin | Predicted: Russian | Actual: Russian
# Name: Babosov | Predicted: Russian | Actual: Russian
# Name: Babst | Predicted: Russian | Actual: Russian
# Name: Babukhin | Predicted: Russian | Actual: Russian
# Name: Badoff | Predicted: Russian | Actual: Russian
# Name: Badukin | Predicted: Russian | Actual: Russian
# Name: Badyashin | Predicted: Russian | Actual: Russian
# Name: Bag | Predicted: Russian | Actual: Russian
# Name: Bagalei | Predicted: Russian | Actual: Russian
# Name: Bagin | Predicted: Russian | Actual: Russian
# Name: Bagramyan | Predicted: Russian | Actual: Russian
# Name: Bagryansky | Predicted: Russian | Actual: Russian
# Name: Bagryantsev | Predicted: Russian | Actual: Russian
# Name: Bahovtsev | Predicted: Russian | Actual: Russian
# Name: Bahrushin | Predicted: Russian | Actual: Russian
# Name: Bahtiarov | Predicted: Russian | Actual: Russian
# Name: Baichorov | Predicted: Russian | Actual: Russian
# Name: Baidin | Predicted: Russian | Actual: Russian
# Name: Baidyuk | Predicted: Russian | Actual: Russian
# Name: Baimakoff | Predicted: Russian | Actual: Russian
# Name: Bairak | Predicted: Russian | Actual: Russian
# Name: Bairov | Predicted: Russian | Actual: Russian
# Name: Baishev | Predicted: Russian | Actual: Russian
# Name: Baitchoroff | Predicted: Russian | Actual: Russian
# Name: Baitoff | Predicted: Russian | Actual: Russian
# Name: Bajenov | Predicted: Russian | Actual: Russian
# Name: Bakadoroff | Predicted: Russian | Actual: Russian
# Name: Bakaleinikoff | Predicted: Russian | Actual: Russian
# Name: Bakanchuk | Predicted: Russian | Actual: Russian
# Name: Bakanov | Predicted: Russian | Actual: Russian
# Name: Bakharev | Predicted: Russian | Actual: Russian
# Name: Bakhelov | Predicted: Russian | Actual: Russian
# Name: Bakhtiaroff | Predicted: Russian | Actual: Russian
# Name: Bakhtiev | Predicted: Russian | Actual: Russian
# Name: Bakhtoff | Predicted: Russian | Actual: Russian
# Name: Bakhtov | Predicted: Russian | Actual: Russian
# Name: Bakin | Predicted: Russian | Actual: Russian
# Name: Bakinoff | Predicted: Russian | Actual: Russian
# Name: Bakirov | Predicted: Russian | Actual: Russian
# ...
# Name: Yushenkov | Predicted: Russian | Actual: Russian
# Name: Yushkov | Predicted: Russian | Actual: Russian
# Name: Yuzhilin | Predicted: Russian | Actual: Russian
# Name: Yuzvishin | Predicted: Russian | Actual: Russian
# Name: Zasuhin | Predicted: Russian | Actual: Russian
# Name: Zelenevsky | Predicted: Russian | Actual: Russian
# Name: Zelenkov | Predicted: Russian | Actual: Russian
# Name: Zenin | Predicted: Russian | Actual: Russian
# Name: Zenzinov | Predicted: Russian | Actual: Russian
# Name: Zhabsky | Predicted: Russian | Actual: Russian
# Name: Zhalilo | Predicted: Russian | Actual: Russian
# Name: Zharikhin | Predicted: Russian | Actual: Russian
# Name: Zharkovsky | Predicted: Russian | Actual: Russian
# Name: Zheldakov | Predicted: Russian | Actual: Russian
# Name: Zhelnov | Predicted: Russian | Actual: Russian
# Name: Zhiboedov | Predicted: Russian | Actual: Russian
# Name: Zhigarev | Predicted: Russian | Actual: Russian
# Name: Zhigin | Predicted: Russian | Actual: Russian
# Name: Zhiharev | Predicted: Russian | Actual: Russian
# Name: Zhilyuk | Predicted: Russian | Actual: Russian
# Name: Zhirikov | Predicted: Russian | Actual: Russian
# Name: Zhivkovich | Predicted: Russian | Actual: Russian
# Name: Zhivopistsev | Predicted: Russian | Actual: Russian
# Name: Zhizha | Predicted: Russian | Actual: Russian
# Name: Zhizhikin | Predicted: Russian | Actual: Russian
# Name: Zhizhnov | Predicted: Russian | Actual: Russian
# Name: Zhluktov | Predicted: Russian | Actual: Russian
# Name: Zhohov | Predicted: Russian | Actual: Russian
# Name: Zhokhin | Predicted: Russian | Actual: Russian
# Name: Zholobov | Predicted: Russian | Actual: Russian
# Name: Zhuravlenko | Predicted: Russian | Actual: Russian
# Name: Zhuravlev | Predicted: Russian | Actual: Russian
# Name: Zhuravliov | Predicted: Russian | Actual: Russian
# Name: Zhurman | Predicted: Russian | Actual: Russian
# Name: Zhuzhlev | Predicted: Russian | Actual: Russian
# Name: Zhuzhnev | Predicted: Russian | Actual: Russian
# Name: Zobnin | Predicted: Russian | Actual: Russian
# Name: Adamczak | Predicted: Polish | Actual: Polish
# Name: Bobienski | Predicted: Russian | Actual: Polish
# Name: Budny | Predicted: Russian | Actual: Polish
# Name: Filipowski | Predicted: Polish | Actual: Polish
# Name: Gomulka | Predicted: Russian | Actual: Polish
# Name: Gorka | Predicted: Russian | Actual: Polish
# Name: Gwozdek | Predicted: Russian | Actual: Polish
# Name: Jaskolski | Predicted: Russian | Actual: Polish
# Name: Kowalski | Predicted: Polish | Actual: Polish
# Name: Maslanka | Predicted: Russian | Actual: Polish
# Name: Niemec | Predicted: English | Actual: Polish
# Name: Slusarski | Predicted: Russian | Actual: Polish
# Name: Sokolsky | Predicted: Russian | Actual: Polish
# Name: Sowka | Predicted: Polish | Actual: Polish
# Name: Zielinski | Predicted: Russian | Actual: Polish
# Name: Ziemniak | Predicted: Russian | Actual: Polish
# Name: Daher | Predicted: Arabic | Actual: Arabic
# Name: Baba | Predicted: Arabic | Actual: Arabic
# Name: Ghanem | Predicted: Arabic | Actual: Arabic
# Name: Antoun | Predicted: Arabic | Actual: Arabic
# Name: Najjar | Predicted: Arabic | Actual: Arabic
# Name: Shalhoub | Predicted: Arabic | Actual: Arabic
# Name: Gaber | Predicted: Arabic | Actual: Arabic
# Name: Cham | Predicted: Arabic | Actual: Arabic
# Name: Shamoun | Predicted: Arabic | Actual: Arabic
# Name: Shamoun | Predicted: Arabic | Actual: Arabic
# Name: Nahas | Predicted: Arabic | Actual: Arabic
# Name: Hadad | Predicted: Arabic | Actual: Arabic
# Name: Sayegh | Predicted: Arabic | Actual: Arabic
# Name: Ganim | Predicted: Arabic | Actual: Arabic
# Name: Tuma | Predicted: Arabic | Actual: Arabic
# Name: Boutros | Predicted: Arabic | Actual: Arabic
# Name: Aswad | Predicted: Arabic | Actual: Arabic
# Name: Dagher | Predicted: Arabic | Actual: Arabic
# Name: Nahas | Predicted: Arabic | Actual: Arabic
# Name: Ganim | Predicted: Arabic | Actual: Arabic
# Name: Salib | Predicted: Arabic | Actual: Arabic
# Name: Hadad | Predicted: Arabic | Actual: Arabic
# Name: Boutros | Predicted: Arabic | Actual: Arabic
# Name: Sabbagh | Predicted: Arabic | Actual: Arabic
# Name: Kouri | Predicted: Arabic | Actual: Arabic
# Name: Malouf | Predicted: Arabic | Actual: Arabic
# Name: Srour | Predicted: Arabic | Actual: Arabic
# Name: Najjar | Predicted: Arabic | Actual: Arabic
# Name: Toma | Predicted: Arabic | Actual: Arabic
# Name: Kalb | Predicted: Arabic | Actual: Arabic
# Name: Sarraf | Predicted: Arabic | Actual: Arabic
# Name: Tahan | Predicted: Arabic | Actual: Arabic
# Name: Said | Predicted: Arabic | Actual: Arabic
# Name: Shalhoub | Predicted: Arabic | Actual: Arabic
# Name: Ghanem | Predicted: Arabic | Actual: Arabic
# Name: Arian | Predicted: English | Actual: Arabic
# Name: Assaf | Predicted: Arabic | Actual: Arabic
# Name: Shadid | Predicted: Arabic | Actual: Arabic
# Name: Sarraf | Predicted: Arabic | Actual: Arabic
# Name: Cham | Predicted: Arabic | Actual: Arabic
# Name: Shamoun | Predicted: Arabic | Actual: Arabic
# Name: Asfour | Predicted: Arabic | Actual: Arabic
# Name: Mifsud | Predicted: Arabic | Actual: Arabic
# Name: Attia | Predicted: Arabic | Actual: Arabic
# Name: Gerges | Predicted: Arabic | Actual: Arabic
# Name: Hajjar | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Basara | Predicted: Arabic | Actual: Arabic
# Name: Asghar | Predicted: Arabic | Actual: Arabic
# Name: Aswad | Predicted: Arabic | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Khouri | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Said | Predicted: Arabic | Actual: Arabic
# Name: Masih | Predicted: Arabic | Actual: Arabic
# Name: Kassis | Predicted: Arabic | Actual: Arabic
# Name: Nazari | Predicted: Arabic | Actual: Arabic
# Name: Arian | Predicted: English | Actual: Arabic
# Name: Asfour | Predicted: Arabic | Actual: Arabic
# Name: Said | Predicted: Arabic | Actual: Arabic
# Name: Koury | Predicted: Arabic | Actual: Arabic
# Name: Amari | Predicted: Arabic | Actual: Arabic
# Name: Srour | Predicted: Arabic | Actual: Arabic
# Name: Abadi | Predicted: Arabic | Actual: Arabic
# Name: Maroun | Predicted: Arabic | Actual: Arabic
# Name: Mifsud | Predicted: Arabic | Actual: Arabic
# Name: Shadid | Predicted: Arabic | Actual: Arabic
# Name: Tannous | Predicted: Arabic | Actual: Arabic
# Name: Ganem | Predicted: Arabic | Actual: Arabic
# Name: Naifeh | Predicted: Arabic | Actual: Arabic
# Name: Asghar | Predicted: Arabic | Actual: Arabic
# Name: Sabbag | Predicted: Arabic | Actual: Arabic
# Name: Kalb | Predicted: Arabic | Actual: Arabic
# Name: Asghar | Predicted: Arabic | Actual: Arabic
# Name: Mikhail | Predicted: Russian | Actual: Arabic
# Name: Safar | Predicted: Arabic | Actual: Arabic
# Name: Haik | Predicted: Arabic | Actual: Arabic
# Name: Nassar | Predicted: Arabic | Actual: Arabic
# Name: Botros | Predicted: Arabic | Actual: Arabic
# Name: Kanaan | Predicted: Arabic | Actual: Arabic
# Name: Nassar | Predicted: Arabic | Actual: Arabic
# Name: Bishara | Predicted: Arabic | Actual: Arabic
# Name: Hakimi | Predicted: Arabic | Actual: Arabic
# Name: Najjar | Predicted: Arabic | Actual: Arabic
# Name: Antar | Predicted: Arabic | Actual: Arabic
# Name: Abboud | Predicted: Arabic | Actual: Arabic
# Name: Tannous | Predicted: Arabic | Actual: Arabic
# Name: Hakimi | Predicted: Arabic | Actual: Arabic
# Name: Baba | Predicted: Arabic | Actual: Arabic
# Name: Qureshi | Predicted: Arabic | Actual: Arabic
# Name: Halabi | Predicted: Arabic | Actual: Arabic
# Name: Haddad | Predicted: Arabic | Actual: Arabic
# Name: Baz | Predicted: Arabic | Actual: Arabic
# Name: Hadad | Predicted: Arabic | Actual: Arabic
# Name: Ba | Predicted: Arabic | Actual: Arabic
# Name: Isa | Predicted: Arabic | Actual: Arabic
# Name: Almasi | Predicted: Arabic | Actual: Arabic
# Name: Srour | Predicted: Arabic | Actual: Arabic
# Name: Asfour | Predicted: Arabic | Actual: Arabic
# Name: Deeb | Predicted: Arabic | Actual: Arabic
# Name: Kalb | Predicted: Arabic | Actual: Arabic
# Name: Ganim | Predicted: Arabic | Actual: Arabic
# Name: Abadi | Predicted: Arabic | Actual: Arabic
# Name: Awad | Predicted: Arabic | Actual: Arabic
# Name: Sleiman | Predicted: Arabic | Actual: Arabic
# Name: Toma | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Ba | Predicted: Arabic | Actual: Arabic
# Name: Zogby | Predicted: Arabic | Actual: Arabic
# Name: Ganem | Predicted: Arabic | Actual: Arabic
# Name: Maloof | Predicted: Arabic | Actual: Arabic
# Name: Hajjar | Predicted: Arabic | Actual: Arabic
# Name: Bishara | Predicted: Arabic | Actual: Arabic
# Name: Cham | Predicted: Arabic | Actual: Arabic
# Name: Kouri | Predicted: Arabic | Actual: Arabic
# Name: Malouf | Predicted: Arabic | Actual: Arabic
# Name: Shamoon | Predicted: Arabic | Actual: Arabic
# Name: Mansour | Predicted: Arabic | Actual: Arabic
# Name: Wasem | Predicted: Arabic | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Guirguis | Predicted: Russian | Actual: Arabic
# Name: Arian | Predicted: English | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Bazzi | Predicted: Arabic | Actual: Arabic
# Name: Botros | Predicted: Arabic | Actual: Arabic
# Name: Rahal | Predicted: Arabic | Actual: Arabic
# Name: Antoun | Predicted: Arabic | Actual: Arabic
# Name: Nassar | Predicted: Arabic | Actual: Arabic
# Name: Hadad | Predicted: Arabic | Actual: Arabic
# Name: Asghar | Predicted: Arabic | Actual: Arabic
# Name: Antoun | Predicted: Arabic | Actual: Arabic
# Name: Shammas | Predicted: Arabic | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Kalb | Predicted: Arabic | Actual: Arabic
# Name: Asfour | Predicted: Arabic | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Sabbag | Predicted: Arabic | Actual: Arabic
# Name: Kanaan | Predicted: Arabic | Actual: Arabic
# Name: Sarraf | Predicted: Arabic | Actual: Arabic
# Name: Aswad | Predicted: Arabic | Actual: Arabic
# Name: Antar | Predicted: Arabic | Actual: Arabic
# Name: Cham | Predicted: Arabic | Actual: Arabic
# Name: Masih | Predicted: Arabic | Actual: Arabic
# Name: Shamon | Predicted: Arabic | Actual: Arabic
# Name: Bata | Predicted: Arabic | Actual: Arabic
# Name: Shamon | Predicted: Arabic | Actual: Arabic
# Name: Quraishi | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Amari | Predicted: Arabic | Actual: Arabic
# Name: Asfour | Predicted: Arabic | Actual: Arabic
# Name: Essa | Predicted: Arabic | Actual: Arabic
# Name: Assaf | Predicted: Arabic | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Isa | Predicted: Arabic | Actual: Arabic
# Name: Baz | Predicted: Arabic | Actual: Arabic
# Name: Kouri | Predicted: Arabic | Actual: Arabic
# Name: Shadid | Predicted: Arabic | Actual: Arabic
# Name: Kanaan | Predicted: Arabic | Actual: Arabic
# Name: Shammas | Predicted: Arabic | Actual: Arabic
# Name: Srour | Predicted: Arabic | Actual: Arabic
# Name: Qureshi | Predicted: Arabic | Actual: Arabic
# Name: Maalouf | Predicted: Arabic | Actual: Arabic
# Name: Sleiman | Predicted: Arabic | Actual: Arabic
# Name: Fakhoury | Predicted: Arabic | Actual: Arabic
# Name: Mifsud | Predicted: Arabic | Actual: Arabic
# Name: Moghadam | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Haddad | Predicted: Arabic | Actual: Arabic
# Name: Nader | Predicted: Arabic | Actual: Arabic
# Name: Ganim | Predicted: Arabic | Actual: Arabic
# Name: Sabbag | Predicted: Arabic | Actual: Arabic
# Name: Wasem | Predicted: Arabic | Actual: Arabic
# Name: Shalhoub | Predicted: Arabic | Actual: Arabic
# Name: Abadi | Predicted: Arabic | Actual: Arabic
# Name: Abboud | Predicted: Arabic | Actual: Arabic
# Name: Sarkis | Predicted: Arabic | Actual: Arabic
# Name: Mustafa | Predicted: Arabic | Actual: Arabic
# Name: Arian | Predicted: English | Actual: Arabic
# Name: Totah | Predicted: Arabic | Actual: Arabic
# Name: Tahan | Predicted: Arabic | Actual: Arabic
# Name: Ha | Predicted: Arabic | Actual: Korean
# Name: Jang | Predicted: Russian | Actual: Korean
# Name: Jong | Predicted: English | Actual: Korean
# Name: Rheem | Predicted: English | Actual: Korean
# Name: San | Predicted: Korean | Actual: Korean
# Name: Seo | Predicted: Japanese | Actual: Korean
# Name: Seok | Predicted: Korean | Actual: Korean
# Name: Suk | Predicted: Korean | Actual: Korean
# Name: Sun | Predicted: Korean | Actual: Korean
# Name: Yim | Predicted: Korean | Actual: Korean
# Name: Abatangelo | Predicted: Italian | Actual: Italian
# Name: Abbiati | Predicted: Italian | Actual: Italian
# Name: Abbracciabene | Predicted: Italian | Actual: Italian
# Name: Abramo | Predicted: Italian | Actual: Italian
# Name: Accardi | Predicted: Italian | Actual: Italian
# Name: Accardo | Predicted: Italian | Actual: Italian
# Name: Acquafredda | Predicted: Italian | Actual: Italian
# Name: Agani | Predicted: Italian | Actual: Italian
# Name: Agrioli | Predicted: Italian | Actual: Italian
# Name: Alescio | Predicted: Italian | Actual: Italian
# Name: Alunni | Predicted: Russian | Actual: Italian
# Name: Ambrogi | Predicted: Italian | Actual: Italian
# Name: Amerighi | Predicted: Italian | Actual: Italian
# Name: Baggi | Predicted: Italian | Actual: Italian
# Name: Baldi | Predicted: Italian | Actual: Italian
# Name: Bassi | Predicted: Italian | Actual: Italian
# Name: Bellini | Predicted: Italian | Actual: Italian
# Name: Bello | Predicted: Italian | Actual: Italian
# Name: Benetton | Predicted: English | Actual: Italian
# Name: Bologna | Predicted: Russian | Actual: Italian
# Name: Boveri | Predicted: Italian | Actual: Italian
# Name: Brivio | Predicted: Italian | Actual: Italian
# Name: Bruno | Predicted: Italian | Actual: Italian
# Name: Capitani | Predicted: Italian | Actual: Italian
# Name: Carideo | Predicted: Italian | Actual: Italian
# Name: Cisternino | Predicted: Italian | Actual: Italian
# Name: Corti | Predicted: Italian | Actual: Italian
# Name: De rege | Predicted: English | Actual: Italian
# Name: Fattore | Predicted: English | Actual: Italian
# Name: Fermi | Predicted: Italian | Actual: Italian
# Name: Ferro | Predicted: Italian | Actual: Italian
# Name: Fiore | Predicted: English | Actual: Italian
# Name: Ganza | Predicted: Russian | Actual: Italian
# Name: Goretti | Predicted: Italian | Actual: Italian
# Name: Greco | Predicted: Italian | Actual: Italian
# Name: Lamon | Predicted: English | Actual: Italian
# Name: Lazzari | Predicted: Italian | Actual: Italian
# Name: Mancini | Predicted: Italian | Actual: Italian
# Name: Manfredonia | Predicted: Italian | Actual: Italian
# Name: Maria | Predicted: Italian | Actual: Italian
# Name: Mondadori | Predicted: Italian | Actual: Italian
# Name: Morandi | Predicted: Italian | Actual: Italian
# Name: Nave | Predicted: English | Actual: Italian
# Name: Nervetti | Predicted: Italian | Actual: Italian
# Name: Nervi | Predicted: Russian | Actual: Italian
# Name: Padovano | Predicted: Italian | Actual: Italian
# Name: Palladino | Predicted: Italian | Actual: Italian
# Name: Palmisano | Predicted: Italian | Actual: Italian
# Name: Panzavecchia | Predicted: Italian | Actual: Italian
# Name: Pesce | Predicted: English | Actual: Italian
# Name: Roncalli | Predicted: Italian | Actual: Italian
# Name: Salvai | Predicted: Italian | Actual: Italian
# Name: Salvatici | Predicted: Italian | Actual: Italian
# Name: Salvay | Predicted: Russian | Actual: Italian
# Name: Sartini | Predicted: Italian | Actual: Italian
# Name: Sebastino | Predicted: Italian | Actual: Italian
# Name: Selvaggio | Predicted: Italian | Actual: Italian
# Name: Sinagra | Predicted: Italian | Actual: Italian
# Name: Tedesco | Predicted: Italian | Actual: Italian
# Name: Toloni | Predicted: Italian | Actual: Italian
# Name: Tornincasa | Predicted: English | Actual: Italian
# Name: Trudu | Predicted: Russian | Actual: Italian
# Name: Zunino | Predicted: Italian | Actual: Italian
#
# Prediction Accuracy: 79.34%
#
# Per-Class Accuracy:
# Portuguese: 0.00%
# Irish: 15.00%
# Spanish: 8.82%
# Vietnamese: 11.11%
# Chinese: 0.00%
# Greek: 55.00%
# Czech: 16.13%
# Dutch: 30.77%
# Japanese: 78.12%
# French: 14.71%
# German: 29.11%
# Scottish: 0.00%
# English: 80.93%
# Russian: 97.65%
# Polish: 25.00%
# Arabic: 96.69%
# Korean: 50.00%
# Italian: 77.78%

# %% [markdown]
# Our model is performing exceptionally well on these languages : Russian, Arabic, Japanese, English, Italian, correctly classifying the vast majority of names. This suggests that the model has learned strong features that distinguish these languages from others. As instance the model is struggling with languages like French, Spanish, Dutch, Portugese ...

# %% [markdown]
# The languages with low accuracy might have fewer samples in the training data, causing the model to not learn their features effectively. Some languages share similar character patterns, making it difficult for the model to distinguish between them like Portuguese and Spanish names may have similar structures.
